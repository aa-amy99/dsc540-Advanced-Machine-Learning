# %% [markdown]
# ## DSC 540 Final Project
# ## Group 4
# ### Team Members: Markus Olson, Sarah Danielson, Amy Aumpansub, Charles Brantley

# %% [markdown]
# ## <font color = blue>Abstract

# %% [markdown]
# This project is a study in the application of data mining and machine learning to build strong classification models to identify the important attributes of voters and other related features that contribute to the success of candidate in winning the election in each county. In general, voter has his/her own expectations on a political party and candidate [1]. It is necessary for political parties to identify their potential voters to maximize the effectiveness of their campaigns and their success rate. By Identifying the important political factors and characteristics of potential voters that contribute to winning an election, it can help politicians to improve their campaign to connect and engage better with voters, so that they have more chance to win the election [2]. In this project, we used the classification analysis as a framework. The 44 independent features including Demographic factors, Surroundings of County factors, Previous Election Results were considered in this study. To develop the strong classification model, we performed various supervised learning algorithms including Decision Tree, Random Forest, Logistic Regression, SVC, and K-Nearest Neighbors Classification. Several Python libraries including Pandas, Matplotlib, NumPy, and Sklearn were utilized in different stages of the KDD process. All developed models have a high accuracy rate, measured by index of accuracy, F1, specificity, precision rates and balanced accuracy score which take an imbalanced class into account. The best model was built with SVC and selected based on its high accuracy and ability to predict the election’s outcome for both target classes. Our study found that the previous election result, age, race, education level of voters in each county have more influence than the surrounding of county factors on whether or not the Democratic or Republican will win the election.

# %% [markdown]
# ## <font color = blue>Introduction

# %% [markdown]
# ### Problem Overview:
# Every political campaign wishes there was a magical way to know who will vote for their candidate. Unfortunately, in the real world, every voter has their own unique expectations for a political party and a politician, and there is no way to guarantee success. Certainly, the 2016 election showed that polls alone are not always accurate. However, by analyzing the demographic makeup of counties, our project aims to understand those characteristics that are more likely to predict a win for a certain political party. This would be useful information for political campaigns to improve their strategies and better engage with voters to raise their likelihood of success.

# %% [markdown]
# ### Project Goals:
# By applying several Machine Learning models to demographics factors of voters, county factors, 2008 and 2012 election results, we hope to build strong clssification models to predict the election outcome and identify those features that were most important to voters to predict the results of the 2016 election. We will analyze these features to better understand what was and was not a factor in the Republican party winning the election in 2016. We analyzed data to address the following questions:
# - 1.  What variables overall are most important to predicting the outcome of an election?
# - 2. What role, if any, do demographic characteristics play in the outcome of an election?

# %% [markdown]
# ### Data:

# %% [markdown]
# - We are using the USA 2016 Presidential Election dataset, retrieved from https://public.opendatasoft.com/explore/dataset/usa-2016-presidential-election-by-county/table/?disjunctive.state.
# - The dataset containing 3143 observations by county
# - The dataset contains 159 independent attributes associated with each county in the US, including numeric attributes such as population and demographic characteristics.
# - Some features are not related to our research questions and project goal, so we removed these from our analysis.
# - We extract our target variable and independent features as follows:

# %% [markdown]
# ## <font color = blue> Exploratory Data Analysis

# %% [markdown]
# #### Target Variable:
#
# - The "target_winner" variable is extracted from the 2016 election columns which indicate the party of the winning candidate in that county. This boolean variable is a "1" if the percentage of votes for Republican candidate in that county is higher than that of Democratic candidate.
#
#
# #### Independent Variables:
# - Our final set of independent variables contains total 44 features, made up of 42 numeric features and 2 categorical features
# - The features can also divided into Demographical and  Political  factors as follows:
# - 1. Demographics Factors contain 37 features of each county, such as race, average education, age ranges, and average income.
# The summary of these features are as follows:
#     - 1.1 A breakdown of the county's education level, which contains 5 features: 'Less Than High School Diploma',
#        'At Least High School Diploma', 'At Least Bachelors's Degree',
#        'Graduate Degree', 'School Enrollment',
#     - 1.2 The median income of the county: 'Median Earnings 2010'
#     - 1.3 A breakdown of the county by race, which contains 6 features: 'White (Not Latino) Population', 'African American Population', 'Native American Population', 'Asian American Population', 'Other Race or Races', 'Latino Population'
#     - 1.4 Wage breakdown of the county, containing 6 features: 'Children Under 6 Living in Poverty',
#        'Adults 65 and Older Living in Poverty', 'Total Population',
#        'Preschool.Enrollment.Ratio.enrolled.ages.3.and.4',
#        'Poverty.Rate.below.federal.poverty.threshold',
#        'Child.Poverty.living.in.families.below.the.poverty.line',
#     - 1.5 The proportions of occupations in the county: 'Management.professional.and.related.occupations',
#        'Service.occupations', 'Sales.and.office.occupations',
#        'Farming.fishing.and.forestry.occupations',
#        'Construction.extraction.maintenance.and.repair.occupations',
#        'Production.transportation.and.material.moving.occupations',
#        'Sire Homogeneity'
#      - 1.6 The age of the average county resident: 'Median Age'
#      - 1.7 Other health conditions: 'Poor.physical.health.days',
#        'Poor.mental.health.days', 'Low.birthweight', 'Teen.births',
#        'Children.in.single.parent.households', 'Adult.smoking',
#        'Adult.obesity', 'Diabetes', 'Sexually.transmitted.infections',
#        'HIV.prevalence.rate', 'Uninsured'
# - 2. Surroundings of county factors contain 5 features
#     - 2.1 The unemployment rate: 'Unemployment'
#     - 2.2 The crime rate: 'Violent.crime'
#     - 2.3 The homicide rate: 'Homicide.rate'
#     - 2.4 The death and infant mortality rates: 'Injury.deaths', 'Infant.mortality'
#
# - 3. Previous election result features contains 2 features which are the election results from the previous presidential election in 2008 and 2012.
#      - 3.1 "2008 winner" is the election result in 2008
#      - 3.2 "2012 winner" is the election result in 2012.

# %% [markdown]
# ## <font color = blue> Data Preprocessing

# %% [markdown]
# - Extracting our target variable and independent features
# - Drop unrelated/extraneous features
# - Create new features computed by the original independent features.
# - Fill in the missing values with the mean values

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import StratifiedKFold, cross_val_predict, cross_val_score

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Load the dataset from UCI
df = pd.read_csv('election.csv', sep=';')

# %%
df.shape
# Out:
# (3143, 159)

# %%
df.head()
# Out:
#             State  ST   Fips                        County  Precincts  \
# 0         Georgia  GA  13089        DeKalb County, Georgia      192.0
# 1           Texas  TX  48487       Wilbarger County, Texas        7.0
# 2        Virginia  VA  51111    Lunenburg County, Virginia       12.0
# 3         Georgia  GA  13297        Walton County, Georgia       21.0
# 4  North Carolina  NC  37011  Avery County, North Carolina       19.0
#
#       Votes  Democrats 08 (Votes)  Democrats 12 (Votes)  \
# 0  295871.0              254594.0              238224.0
# 1    4101.0                1196.0                 971.0
# 2    5577.0                2703.0                2684.0
# 3   40425.0                8469.0                8148.0
# 4    8060.0                2178.0                1882.0
#
#    Republicans 08 (Votes)  Republicans 12 (Votes)  ...   total08   total12  \
# 0                 65581.0                 64392.0  ...  322304.0  306265.0
# 1                  3283.0                  2956.0  ...    4509.0    3980.0
# 2                  2900.0                  2969.0  ...    5650.0    5734.0
# 3                 27253.0                 29036.0  ...   36026.0   37612.0
# 4                  5681.0                  5766.0  ...    7943.0    7759.0
#
#    other08  other12  Other12 Frac  Other08 Frac  Rep12 Frac2  Rep08 Frac2  \
# 0   2129.0   3649.0      0.011915      0.006606     0.212785     0.204829
# 1     30.0     53.0      0.013317      0.006653     0.752737     0.732976
# 2     47.0     81.0      0.014126      0.008319     0.525208     0.517580
# 3    304.0    428.0      0.011379      0.008438     0.780873     0.762919
# 4     84.0    111.0      0.014306      0.010575     0.753923     0.722866
#
#    Dem12 Frac2  Dem08 Frac2
# 0     0.787215     0.795171
# 1     0.247263     0.267024
# 2     0.474792     0.482420
# 3     0.219127     0.237081
# 4     0.246077     0.277134
#
# [5 rows x 159 columns]

# %% [markdown]
# - The dataset contains 3143 rows, where each row represents a county
# - The dataset contains 159 independent attributes associated with that county, including the numeric attributes such as Fips, Precincts, Votes, and Demographic characteristics of voters and the text attributes such as geo shape, candidate's names. Some features are not related to our research questions and project goal, so we will extract our own set of features.

# %%
df.describe(include='all')
# Out:
#         State    ST          Fips                    County    Precincts  \
# count    3143  3142   3143.000000                      3143  3111.000000
# unique     51    51           NaN                      3143          NaN
# top     Texas    TX           NaN  Wyoming County, New York          NaN
# freq      254   254           NaN                         1          NaN
# mean      NaN   NaN  30390.411709                       NaN    54.927997
# std       NaN   NaN  15164.717720                       NaN   172.872053
# min       NaN   NaN   1001.000000                       NaN     1.000000
# 25%       NaN   NaN  18178.000000                       NaN    11.000000
# 50%       NaN   NaN  29177.000000                       NaN    20.000000
# 75%       NaN   NaN  45082.000000                       NaN    38.000000
# max       NaN   NaN  56045.000000                       NaN  4988.000000
#
#                Votes  Democrats 08 (Votes)  Democrats 12 (Votes)  \
# count   3.111000e+03          3.112000e+03          3.112000e+03
# unique           NaN                   NaN                   NaN
# top              NaN                   NaN                   NaN
# freq             NaN                   NaN                   NaN
# mean    4.176518e+04          2.229240e+04          2.113845e+04
# std     1.134234e+05          7.714042e+04          7.423506e+04
# min     6.400000e+01          8.000000e+00          5.000000e+00
# 25%     4.837000e+03          1.810000e+03          1.558250e+03
# 50%     1.094800e+04          4.505500e+03          3.999000e+03
# 75%     2.880700e+04          1.238600e+04          1.136500e+04
# max     2.652072e+06          2.295853e+06          2.216903e+06
#
#         Republicans 08 (Votes)  Republicans 12 (Votes)  ...       total08  \
# count              3112.000000             3112.000000  ...  3.112000e+03
# unique                     NaN                     NaN  ...           NaN
# top                        NaN                     NaN  ...           NaN
# freq                       NaN                     NaN  ...           NaN
# mean              19201.429306            19526.023136  ...  4.208700e+04
# std               44865.312835            44782.529305  ...  1.199522e+05
# min                  67.000000               54.000000  ...  7.900000e+01
# 25%                2881.250000             2918.000000  ...  4.974750e+03
# 50%                6312.000000             6450.500000  ...  1.105800e+04
# 75%               16036.000000            16330.000000  ...  2.916075e+04
# max              956425.000000           885333.000000  ...  3.318248e+06
#
#              total12       other08       other12  Other12 Frac  Other08 Frac  \
# count   3.112000e+03   3112.000000   3112.000000   3112.000000   3112.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    4.138286e+04    593.165810    718.383355      0.018472      0.016468
# std     1.170526e+05   1856.868432   2310.513184      0.009095      0.008552
# min     6.400000e+01      0.000000      0.000000      0.000000      0.000000
# 25%     4.837500e+03     71.000000     74.000000      0.012308      0.010618
# 50%     1.080150e+04    169.500000    181.500000      0.017343      0.015728
# 75%     2.847075e+04    446.000000    517.250000      0.023933      0.020763
# max     3.181067e+06  65970.000000  78831.000000      0.082317      0.072893
#
#         Rep12 Frac2  Rep08 Frac2  Dem12 Frac2  Dem08 Frac2
# count   3112.000000  3112.000000  3112.000000  3112.000000
# unique          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN
# mean       0.607775     0.577527     0.392225     0.422473
# std        0.150378     0.140607     0.150378     0.140607
# min        0.060160     0.065992     0.034722     0.050314
# 25%        0.515391     0.486565     0.283582     0.319085
# 50%        0.620527     0.581609     0.379473     0.418391
# 75%        0.716418     0.680915     0.484609     0.513435
# max        0.965278     0.949686     0.939840     0.934008
#
# [11 rows x 159 columns]

# %% [markdown]
# #### 3143 entries, 159 columns.  dtypes: float64(147), int64(2), object(10)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3143 entries, 0 to 3142
# Data columns (total 159 columns):
#  #   Column                                                      Dtype
# ---  ------                                                      -----
#  0   State                                                       object
#  1   ST                                                          object
#  2   Fips                                                        int64
#  3   County                                                      object
#  4   Precincts                                                   float64
#  5   Votes                                                       float64
#  6   Democrats 08 (Votes)                                        float64
#  7   Democrats 12 (Votes)                                        float64
#  8   Republicans 08 (Votes)                                      float64
#  9   Republicans 12 (Votes)                                      float64
#  10  Republicans 2016                                            float64
#  11  Democrats 2016                                              float64
#  12  Green 2016                                                  float64
#  13  Libertarians 2016                                           float64
#  14  Republicans 2012                                            float64
#  15  Republicans 2008                                            float64
#  16  Democrats 2012                                              float64
#  17  Democrats 2008                                              float64
#  18  Less Than High School Diploma                               float64
#  19  At Least High School Diploma                                float64
#  20  At Least Bachelors's Degree                                 float64
#  21  Graduate Degree                                             float64
#  22  School Enrollment                                           float64
#  23  Median Earnings 2010                                        float64
#  24  White (Not Latino) Population                               float64
#  25  African American Population                                 float64
#  26  Native American Population                                  float64
#  27  Asian American Population                                   float64
#  28  Other Race or Races                                         float64
#  29  Latino Population                                           float64
#  30  Children Under 6 Living in Poverty                          float64
#  31  Adults 65 and Older Living in Poverty                       float64
#  32  Total Population                                            int64
#  33  Preschool.Enrollment.Ratio.enrolled.ages.3.and.4            float64
#  34  Poverty.Rate.below.federal.poverty.threshold                float64
#  35  Gini.Coefficient                                            float64
#  36  Child.Poverty.living.in.families.below.the.poverty.line     float64
#  37  Management.professional.and.related.occupations             float64
#  38  Service.occupations                                         float64
#  39  Sales.and.office.occupations                                float64
#  40  Farming.fishing.and.forestry.occupations                    float64
#  41  Construction.extraction.maintenance.and.repair.occupations  float64
#  42  Production.transportation.and.material.moving.occupations   float64
#  43  White                                                       float64
#  44  Black                                                       float64
#  45  Hispanic                                                    float64
#  46  Asian                                                       float64
#  47  Amerindian                                                  float64
#  48  Other                                                       float64
#  49  White  Asian                                                float64
#  50  Sire Homogeneity                                            float64
#  51  Median Age                                                  float64
#  52  lon                                                         float64
#  53  lat                                                         float64
#  54  Poor.physical.health.days                                   float64
#  55  Poor.mental.health.days                                     float64
#  56  Low.birthweight                                             float64
#  57  Teen.births                                                 float64
#  58  Children.in.single.parent.households                        float64
#  59  Adult.smoking                                               float64
#  60  Adult.obesity                                               float64
#  61  Diabetes                                                    float64
#  62  Sexually.transmitted.infections                             float64
#  63  HIV.prevalence.rate                                         float64
#  64  Uninsured                                                   float64
#  65  Unemployment                                                float64
#  66  Violent.crime                                               float64
#  67  Homicide.rate                                               float64
#  68  Injury.deaths                                               float64
#  69  Infant.mortality                                            float64
#  70  CA                                                          float64
#  71  S                                                           float64
#  72  MAR                                                         float64
#  73  CFS                                                         float64
#  74  ACFS                                                        float64
#  75  Mean Alc                                                    float64
#  76  Max Alc                                                     float64
#  77  Mixedness                                                   float64
#  78  elevation                                                   float64
#  79  Annual Prcp                                                 float64
#  80  Winter Prcp                                                 float64
#  81  Summer Prcp                                                 float64
#  82  Spring Prcp                                                 float64
#  83  Autumn Prcp                                                 float64
#  84  Annual Tavg                                                 float64
#  85  Annual Tmax                                                 float64
#  86  Annual Tmin                                                 float64
#  87  Winter Tavg                                                 float64
#  88  Winter Tmax                                                 float64
#  89  Winter Tmin                                                 float64
#  90  Summer Tavg                                                 float64
#  91  Summer Tmax                                                 float64
#  92  Summer Tmin                                                 float64
#  93  Spring Tavg                                                 float64
#  94  Spring Tmax                                                 float64
#  95  Spring Tmin                                                 float64
#  96  Autumn Tavg                                                 float64
#  97  Autumn Tmax                                                 float64
#  98  Autumn Tmin                                                 float64
#  99  Nearest County                                              float64
#  100 temp                                                        float64
#  101 precip                                                      float64
#  102 Temp Bins                                                   object
#  103 Lat Bins                                                    float64
#  104 Lon Bins                                                    object
#  105 Precip Bins                                                 object
#  106 Elevation Bins                                              object
#  107 Geo Shape                                                   object
#  108 Name 16                                                     object
#  109 reporting                                                   float64
#  110 Votes16 Trumpd                                              float64
#  111 Votes16 Clintonh                                            float64
#  112 Votes16 Johnsong                                            float64
#  113 Votes16 Steinj                                              float64
#  114 Votes16 Castled                                             float64
#  115 Votes16 De La Fuenter                                       float64
#  116 Est Votes Remaining                                         float64
#  117 Votes16 Mcmulline                                           float64
#  118 Votes16 Hedgesj                                             float64
#  119 Votes16 Kahnl                                               float64
#  120 Votes16 La Rivag                                            float64
#  121 Votes16 Hoeflingt                                           float64
#  122 Votes16 Kenistonc                                           float64
#  123 Votes16 Smithm                                              float64
#  124 Votes16 Atwoodf                                             float64
#  125 Votes16 Kennedya                                            float64
#  126 Votes16 Kopitkek                                            float64
#  127 Votes16 Kotlikoffl                                          float64
#  128 Votes16 Lyttleb                                             float64
#  129 Votes16 Maldonadoj                                          float64
#  130 Votes16 Maturenm                                            float64
#  131 Votes16 Scottr                                              float64
#  132 Votes16 Silvar                                              float64
#  133 Votes16 Soltysike                                           float64
#  134 Votes16 Vacekd                                              float64
#  135 Votes16 Copelands                                           float64
#  136 Votes16 Jacobp                                              float64
#  137 Votes16 Whitej                                              float64
#  138 Votes16 Mooreheadm                                          float64
#  139 Votes16 None Of These Candidates                            float64
#  140 Votes16 Duncanr                                             float64
#  141 Votes16 Skewesp                                             float64
#  142 Votes16 Giordanir                                           float64
#  143 total16                                                     float64
#  144 Other16 Frac                                                float64
#  145 Rep16 Frac2                                                 float64
#  146 Dem16 Frac2                                                 float64
#  147 Name Prev                                                   object
#  148 Statecode Prev                                              float64
#  149 total08                                                     float64
#  150 total12                                                     float64
#  151 other08                                                     float64
#  152 other12                                                     float64
#  153 Other12 Frac                                                float64
#  154 Other08 Frac                                                float64
#  155 Rep12 Frac2                                                 float64
#  156 Rep08 Frac2                                                 float64
#  157 Dem12 Frac2                                                 float64
#  158 Dem08 Frac2                                                 float64
# dtypes: float64(147), int64(2), object(10)
# memory usage: 3.8+ MB

# %% [markdown]
# #### 10 columns are object datatypes

# %%
print(df.select_dtypes(include='object').columns)
# Out:
# Index(['State', 'ST', 'County', 'Temp Bins', 'Lon Bins', 'Precip Bins',
#        'Elevation Bins', 'Geo Shape', 'Name 16', 'Name Prev'],
#       dtype='object')

# %%
df.select_dtypes(include='object')
# Out:
#                State  ST                           County  Temp Bins  \
# 0            Georgia  GA           DeKalb County, Georgia  14.9,16.6
# 1              Texas  TX          Wilbarger County, Texas  16.6,18.5
# 2           Virginia  VA       Lunenburg County, Virginia        NaN
# 3            Georgia  GA           Walton County, Georgia        NaN
# 4     North Carolina  NC     Avery County, North Carolina  8.12,9.33
# ...              ...  ..                              ...        ...
# 3138       Tennessee  TN          Obion County, Tennessee        NaN
# 3139        Michigan  MI          Macomb County, Michigan        NaN
# 3140   West Virginia  WV    Braxton County, West Virginia        NaN
# 3141  North Carolina  NC  Mitchell County, North Carolina  10.7,12.0
# 3142        Maryland  MD      Dorchester County, Maryland  13.6,14.9
#
#            Lon Bins          Precip Bins       Elevation Bins  \
# 0     (-84.5,-82.1]  (1.27e+03,1.39e+03]            (259,317]
# 1      (-100,-96.7]            (628,818]            (317,396]
# 2     (-82.1,-78.2]                  NaN                  NaN
# 3     (-84.5,-82.1]                  NaN                  NaN
# 4     (-82.1,-78.2]  (1.27e+03,1.39e+03]  (1.01e+03,3.06e+03]
# ...             ...                  ...                  ...
# 3138  (-90.4,-87.2]  (1.27e+03,1.39e+03]           (38.9,105]
# 3139  (-84.5,-82.1]            (818,932]            (167,216]
# 3140  (-82.1,-78.2]  (1.19e+03,1.27e+03]            (216,259]
# 3141  (-84.5,-82.1]                  NaN       (572,1.01e+03]
# 3142    (-78.2,178]  (1.03e+03,1.12e+03]         [-12.3,38.9]
#
#                                               Geo Shape     Name 16  \
# 0     {"type": "Polygon", "coordinates": [[[-84.3484...      DeKalb
# 1     {"type": "Polygon", "coordinates": [[[-99.4752...   Wilbarger
# 2     {"type": "Polygon", "coordinates": [[[-78.3973...   Lunenburg
# 3     {"type": "Polygon", "coordinates": [[[-83.9156...      Walton
# 4     {"type": "Polygon", "coordinates": [[[-82.0164...       Avery
# ...                                                 ...         ...
# 3138  {"type": "Polygon", "coordinates": [[[-89.2563...       Obion
# 3139  {"type": "Polygon", "coordinates": [[[-82.7292...      Macomb
# 3140  {"type": "Polygon", "coordinates": [[[-80.9333...     Braxton
# 3141  {"type": "Polygon", "coordinates": [[[-82.2451...    Mitchell
# 3142  {"type": "Polygon", "coordinates": [[[-75.9705...  Dorchester
#
#        Name Prev
# 0         DeKalb
# 1      Wilbarger
# 2      Lunenburg
# 3         Walton
# 4          Avery
# ...          ...
# 3138       Obion
# 3139      Macomb
# 3140     Braxton
# 3141    Mitchell
# 3142  Dorchester
#
# [3143 rows x 10 columns]

# %% [markdown]
# ### 1. Create new target column "target_winner" and drop rows with missing values to extract target label
# #### 1 = Republicans won, 0 = Democrats won

# %%
# Drop the rows with missing target variable
print(df['Republicans 2016'].isnull().sum())
print(df['Democrats 2016'].isnull().sum())
# Out:
# 32
# 32

# %%
df = df.dropna(subset=['Republicans 2016', 'Democrats 2016'])

# %%
print(df['Republicans 2016'].isnull().sum())
print(df['Democrats 2016'].isnull().sum())
df.shape
# Out:
# 0
# 0
# (3111, 159)

# %%
conditions = [
    (df['Republicans 2016'] > df['Democrats 2016']),
    (df['Republicans 2016'] < df['Democrats 2016'])]
choices = [1,0]

df["target_winner"] = np.select(conditions, choices, default='null')
df["target_winner"] = df["target_winner"].astype(int)

# %%
df["target_winner"][:5]
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: target_winner, dtype: int64

# %%
df['Republicans 2016'][:5]
# Out:
# 0    16.064771
# 1    77.200683
# 2    57.486104
# 3    76.915275
# 4    77.245658
# Name: Republicans 2016, dtype: float64

# %%
df['Democrats 2016'][:5]
# Out:
# 0    80.822723
# 1    19.678127
# 2    39.913932
# 3    20.479901
# 4    20.719603
# Name: Democrats 2016, dtype: float64

# %% [markdown]
# ### 2. Drop unrelated columns

# %% [markdown]
# #### Demographics

# %%
del_list= list(df)[2:3] + list(df)[4:14] + list(df)[35:36] +list(df)[43:50] +list(df)[52:54] + list(df)[70:-1]

# %%
print(del_list)
# Out:
# ['Fips', 'Precincts', 'Votes', 'Democrats 08 (Votes)', 'Democrats 12 (Votes)', 'Republicans 08 (Votes)', 'Republicans 12 (Votes)', 'Republicans 2016', 'Democrats 2016', 'Green 2016', 'Libertarians 2016', 'Gini.Coefficient', 'White', 'Black', 'Hispanic', 'Asian', 'Amerindian', 'Other', 'White  Asian', 'lon', 'lat', 'CA', 'S', 'MAR', 'CFS', 'ACFS', 'Mean Alc', 'Max Alc', 'Mixedness', 'elevation', 'Annual Prcp', 'Winter Prcp', 'Summer Prcp', 'Spring Prcp', 'Autumn Prcp', 'Annual Tavg', 'Annual Tmax', 'Annual Tmin', 'Winter Tavg', 'Winter Tmax', 'Winter Tmin', 'Summer Tavg', 'Summer Tmax', 'Summer Tmin', 'Spring Tavg', 'Spring Tmax', 'Spring Tmin', 'Autumn Tavg', 'Autumn Tmax', 'Autumn Tmin', 'Nearest County', 'temp', 'precip', 'Temp Bins', 'Lat Bins', 'Lon Bins', 'Precip Bins', 'Elevation Bins', 'Geo Shape', 'Name 16', 'reporting', 'Votes16 Trumpd', 'Votes16 Clintonh', 'Votes16 Johnsong', 'Votes16 Steinj', 'Votes16 Castled', 'Votes16 De La Fuenter', 'Est Votes Remaining', 'Votes16 Mcmulline', 'Votes16 Hedgesj', 'Votes16 Kahnl', 'Votes16 La Rivag', 'Votes16 Hoeflingt', 'Votes16 Kenistonc', 'Votes16 Smithm', 'Votes16 Atwoodf', 'Votes16 Kennedya', 'Votes16 Kopitkek', 'Votes16 Kotlikoffl', 'Votes16 Lyttleb', 'Votes16 Maldonadoj', 'Votes16 Maturenm', 'Votes16 Scottr', 'Votes16 Silvar', 'Votes16 Soltysike', 'Votes16 Vacekd', 'Votes16 Copelands', 'Votes16 Jacobp', 'Votes16 Whitej', 'Votes16 Mooreheadm', 'Votes16 None Of These Candidates', 'Votes16 Duncanr', 'Votes16 Skewesp', 'Votes16 Giordanir', 'total16', 'Other16 Frac', 'Rep16 Frac2', 'Dem16 Frac2', 'Name Prev', 'Statecode Prev', 'total08', 'total12', 'other08', 'other12', 'Other12 Frac', 'Other08 Frac', 'Rep12 Frac2', 'Rep08 Frac2', 'Dem12 Frac2', 'Dem08 Frac2']

# %%
df2 = df.drop(del_list, axis=1)

# %%
df2.columns
# Out:
# Index(['State', 'ST', 'County', 'Republicans 2012', 'Republicans 2008',
#        'Democrats 2012', 'Democrats 2008', 'Less Than High School Diploma',
#        'At Least High School Diploma', 'At Least Bachelors's Degree',
#        'Graduate Degree', 'School Enrollment', 'Median Earnings 2010',
#        'White (Not Latino) Population', 'African American Population',
#        'Native American Population', 'Asian American Population',
#        'Other Race or Races', 'Latino Population',
#        'Children Under 6 Living in Poverty',
#        'Adults 65 and Older Living in Poverty', 'Total Population',
#        'Preschool.Enrollment.Ratio.enrolled.ages.3.and.4',
#        'Poverty.Rate.below.federal.poverty.threshold',
#        'Child.Poverty.living.in.families.below.the.poverty.line',
#        'Management.professional.and.related.occupations',
#        'Service.occupations', 'Sales.and.office.occupations',
#        'Farming.fishing.and.forestry.occupations',
#        'Construction.extraction.maintenance.and.repair.occupations',
#        'Production.transportation.and.material.moving.occupations',
#        'Sire Homogeneity', 'Median Age', 'Poor.physical.health.days',
#        'Poor.mental.health.days', 'Low.birthweight', 'Teen.births',
#        'Children.in.single.parent.households', 'Adult.smoking',
#        'Adult.obesity', 'Diabetes', 'Sexually.transmitted.infections',
#        'HIV.prevalence.rate', 'Uninsured', 'Unemployment', 'Violent.crime',
#        'Homicide.rate', 'Injury.deaths', 'Infant.mortality', 'target_winner'],
#       dtype='object')

# %% [markdown]
# ### 3. Create new features for winner in 2008 and 2012

# %% [markdown]
# #### Change 2008 and 2012 election results into Boolean

# %% [markdown]
# ##### Changing 2008

# %%
print(df2['Republicans 2008'].isnull().sum())
print(df2['Democrats 2008'].isnull().sum())
# Out:
# 0
# 0

# %%
conditions08 = [
    (df2['Republicans 2008'] > df2['Democrats 2008']),
    (df2['Republicans 2008'] < df2['Democrats 2008'])]
choices = [1,0]

df2["2008 winner"] = np.select(conditions08, choices, default='null')
df2["2008 winner"] = df2["2008 winner"].astype(int)

# %%
df2["2008 winner"][:5]
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: 2008 winner, dtype: int64

# %%
df2['Republicans 2008'][:5]
# Out:
# 0    20.347560
# 1    72.809936
# 2    51.327434
# 3    75.648143
# 4    71.522095
# Name: Republicans 2008, dtype: float64

# %%
df2['Democrats 2008'][:5]
# Out:
# 0    78.991883
# 1    26.524728
# 2    47.840708
# 3    23.508022
# 4    27.420370
# Name: Democrats 2008, dtype: float64

# %% [markdown]
# ##### Changing 2012

# %%
print(df2['Republicans 2012'].isnull().sum())
print(df2['Democrats 2012'].isnull().sum())
# Out:
# 0
# 0

# %%
conditions12 = [
    (df2['Republicans 2012'] > df2['Democrats 2012']),
    (df2['Republicans 2012'] < df2['Democrats 2012'])]
choices = [1,0]

df2["2012 winner"] = np.select(conditions12, choices, default='null')
df2["2012 winner"] = df2["2012 winner"].astype(int)

# %%
df2["2012 winner"][:5]
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: 2012 winner, dtype: int64

# %%
df2['Republicans 2012'][:5]
# Out:
# 0    21.024929
# 1    74.271357
# 2    51.778863
# 3    77.198766
# 4    74.313700
# Name: Republicans 2012, dtype: float64

# %%
df2['Democrats 2012'][:5]
# Out:
# 0    77.783619
# 1    24.396985
# 2    46.808511
# 3    21.663299
# 4    24.255703
# Name: Democrats 2012, dtype: float64

# %% [markdown]
# #### Now we can remove 2012 and 2008 Republican/Democrat results from df2

# %%
drop_these =['Democrats 2012', 'Republicans 2012', 'Democrats 2008', 'Republicans 2008']

# %%
df3 = df2.drop(drop_these, axis=1)

# %%
df3.shape
# Out:
# (3111, 48)

# %%
df3.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3111 entries, 0 to 3142
# Data columns (total 48 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   State                                                       3111 non-null   object
#  1   ST                                                          3111 non-null   object
#  2   County                                                      3111 non-null   object
#  3   Less Than High School Diploma                               3111 non-null   float64
#  4   At Least High School Diploma                                3111 non-null   float64
#  5   At Least Bachelors's Degree                                 3111 non-null   float64
#  6   Graduate Degree                                             3111 non-null   float64
#  7   School Enrollment                                           3111 non-null   float64
#  8   Median Earnings 2010                                        3111 non-null   float64
#  9   White (Not Latino) Population                               3111 non-null   float64
#  10  African American Population                                 3111 non-null   float64
#  11  Native American Population                                  3111 non-null   float64
#  12  Asian American Population                                   3111 non-null   float64
#  13  Other Race or Races                                         3111 non-null   float64
#  14  Latino Population                                           3111 non-null   float64
#  15  Children Under 6 Living in Poverty                          3111 non-null   float64
#  16  Adults 65 and Older Living in Poverty                       3111 non-null   float64
#  17  Total Population                                            3111 non-null   int64
#  18  Preschool.Enrollment.Ratio.enrolled.ages.3.and.4            3104 non-null   float64
#  19  Poverty.Rate.below.federal.poverty.threshold                3111 non-null   float64
#  20  Child.Poverty.living.in.families.below.the.poverty.line     3111 non-null   float64
#  21  Management.professional.and.related.occupations             3111 non-null   float64
#  22  Service.occupations                                         3111 non-null   float64
#  23  Sales.and.office.occupations                                3111 non-null   float64
#  24  Farming.fishing.and.forestry.occupations                    3111 non-null   float64
#  25  Construction.extraction.maintenance.and.repair.occupations  3111 non-null   float64
#  26  Production.transportation.and.material.moving.occupations   3111 non-null   float64
#  27  Sire Homogeneity                                            3111 non-null   float64
#  28  Median Age                                                  3111 non-null   float64
#  29  Poor.physical.health.days                                   2779 non-null   float64
#  30  Poor.mental.health.days                                     2562 non-null   float64
#  31  Low.birthweight                                             2897 non-null   float64
#  32  Teen.births                                                 3021 non-null   float64
#  33  Children.in.single.parent.households                        3110 non-null   float64
#  34  Adult.smoking                                               2684 non-null   float64
#  35  Adult.obesity                                               3111 non-null   float64
#  36  Diabetes                                                    3111 non-null   float64
#  37  Sexually.transmitted.infections                             2930 non-null   float64
#  38  HIV.prevalence.rate                                         2310 non-null   float64
#  39  Uninsured                                                   3111 non-null   float64
#  40  Unemployment                                                3111 non-null   float64
#  41  Violent.crime                                               2944 non-null   float64
#  42  Homicide.rate                                               1245 non-null   float64
#  43  Injury.deaths                                               2826 non-null   float64
#  44  Infant.mortality                                            1407 non-null   float64
#  45  target_winner                                               3111 non-null   int64
#  46  2008 winner                                                 3111 non-null   int64
#  47  2012 winner                                                 3111 non-null   int64
# dtypes: float64(41), int64(4), object(3)
# memory usage: 1.2+ MB

# %% [markdown]
# ### 4. Missing Values - filling missing numeric values with the mean

# %%
df3.isnull().values.sum()
# Out:
# 6624

# %%
df3 = df3.fillna(df3.mean())

# %%
df3.head()
# Out:
#             State  ST                        County  \
# 0         Georgia  GA        DeKalb County, Georgia
# 1           Texas  TX       Wilbarger County, Texas
# 2        Virginia  VA    Lunenburg County, Virginia
# 3         Georgia  GA        Walton County, Georgia
# 4  North Carolina  NC  Avery County, North Carolina
#
#    Less Than High School Diploma  At Least High School Diploma  \
# 0                           12.1                          87.9
# 1                           26.4                          73.6
# 2                           28.5                          71.5
# 3                           19.6                          80.4
# 4                           18.7                          81.3
#
#    At Least Bachelors's Degree  Graduate Degree  School Enrollment  \
# 0                         38.7             15.1              76.15
# 1                         15.9              5.9              69.25
# 2                         10.0              3.0              72.35
# 3                         17.3              5.3              73.75
# 4                         20.3              6.0              76.25
#
#    Median Earnings 2010  White (Not Latino) Population  ...  \
# 0           31275.05492                          30.05  ...
# 1           22438.66508                          63.30  ...
# 2           24528.98095                          59.30  ...
# 3           29155.95143                          78.90  ...
# 4           19670.20603                          89.85  ...
#
#    HIV.prevalence.rate  Uninsured  Unemployment  Violent.crime  Homicide.rate  \
# 0               1080.4      0.239         0.093         623.17      13.970000
# 1                140.0      0.246         0.046         411.60       6.262827
# 2                239.0      0.191         0.084         182.27       6.262827
# 3                102.2      0.203         0.085         231.26       4.350000
# 4                 57.5      0.255         0.112         126.53       6.262827
#
#    Injury.deaths  Infant.mortality  target_winner  2008 winner  2012 winner
# 0           51.7          8.500000              0            0            0
# 1           70.4          7.729495              1            1            1
# 2           92.5          7.729495              1            1            1
# 3           59.7          7.800000              1            1            1
# 4           80.2          7.729495              1            1            1
#
# [5 rows x 48 columns]

# %%
df3.isnull().values.sum()
# Out:
# 0

# %%
df3.shape
# Out:
# (3111, 48)

# %% [markdown]
# #### Data is now cleaned

# %% [markdown]
# ## <font color = blue> Data Exploration

# %% [markdown]
# #### Basic Statistics

# %%
df3.describe()
# Out:
#        Less Than High School Diploma  At Least High School Diploma  \
# count                    3111.000000                   3111.000000
# mean                       16.912633                     83.023079
# std                         7.336561                      7.483062
# min                         0.700000                     29.900000
# 25%                        11.500000                     78.400000
# 50%                        15.400000                     84.600000
# 75%                        21.600000                     88.500000
# max                        52.100000                     99.300000
#
#        At Least Bachelors's Degree  Graduate Degree  School Enrollment  \
# count                  3111.000000      3111.000000        3111.000000
# mean                     18.997686         6.444536          75.014433
# std                       8.654629         3.854720           5.024146
# min                       3.700000         0.000000          38.000000
# 25%                      13.100000         4.000000          72.350000
# 50%                      16.800000         5.300000          75.200000
# 75%                      22.550000         7.700000          77.950000
# max                      71.000000        40.600000         100.000000
#
#        Median Earnings 2010  White (Not Latino) Population  \
# count           3111.000000                    3111.000000
# mean           25435.382819                      79.078865
# std             5033.530215                      19.294142
# min                0.000000                       2.500000
# 25%            22328.710478                      68.050000
# 50%            24798.574605                      86.550000
# 75%            27523.054762                      94.350000
# max            56674.350795                      99.200000
#
#        African American Population  Native American Population  \
# count                  3111.000000                 3111.000000
# mean                      8.831517                    1.512922
# std                      14.441820                    6.114983
# min                       0.000000                    0.000000
# 25%                       0.400000                    0.150000
# 50%                       2.000000                    0.300000
# 75%                      10.100000                    0.650000
# max                      86.100000                   85.900000
#
#        Asian American Population  ...  HIV.prevalence.rate   Uninsured  \
# count                3111.000000  ...          3111.000000  3111.00000
# mean                    1.066956  ...           174.856017     0.17913
# std                     2.242198  ...           197.916044     0.05404
# min                     0.000000  ...            11.000000     0.03100
# 25%                     0.250000  ...            71.800000     0.13950
# 50%                     0.450000  ...           162.700000     0.17700
# 75%                     1.000000  ...           174.856017     0.21300
# max                    42.700000  ...          3764.100000     0.38900
#
#        Unemployment  Violent.crime  Homicide.rate  Injury.deaths  \
# count   3111.000000    3111.000000    3111.000000    3111.000000
# mean       0.076888     256.412476       6.262827      75.734006
# std        0.027501     201.412171       2.934566      22.411738
# min        0.008000       0.000000       0.610000      23.300000
# 25%        0.058000     120.095000       6.262827      60.750000
# 50%        0.075000     213.470000       6.262827      75.400000
# 75%        0.093000     328.165000       6.262827      86.400000
# max        0.283000    1989.540000      51.490000     257.300000
#
#        Infant.mortality  target_winner  2008 winner  2012 winner
# count       3111.000000    3111.000000  3111.000000  3111.000000
# mean           7.729495       0.843780     0.719061     0.777563
# std            1.679761       0.363122     0.449530     0.415950
# min            2.600000       0.000000     0.000000     0.000000
# 25%            7.600000       1.000000     0.000000     1.000000
# 50%            7.729495       1.000000     1.000000     1.000000
# 75%            7.729495       1.000000     1.000000     1.000000
# max           19.600000       1.000000     1.000000     1.000000
#
# [8 rows x 45 columns]

# %% [markdown]
# - The standard deviation above shows that some variables have large differences in their values.
# - The 'Median Earnings', the 'Crime Rate', and the 'At least High School Diploma' variables have a large standard deviations, implying a large spread of their values.
# - The 'Median Earnings' variable has the largest value of 56,674.00.
# - The 'Median Earnings', 'African American Population', 'Native American Population', among several others, have the smallest value of 0.0.

# %% [markdown]
# #### Correlation Analysis

# %%
corr = df3.corr()
f, ax = plt.subplots(figsize=(50, 50))
t= f.suptitle('Features Correlation Heatmap', fontsize=18)
hm = sns.heatmap(round(corr,2), annot=True, ax=ax, cmap="coolwarm",fmt='.2f', linewidths=.05)
f.subplots_adjust(top=0.95)

# %% [markdown]
# - From the heatmap, the 'At Least Bachelors's Degree' variable is highly positively correlated with the 'Graduate Degree' variables, with the correlation values over 0.92, indicated in red color in the above heatmap.
# - The election results in 2008 and 2012 are also highly correlated.
# - The 'Median Earnings' is moderately positively correlated with the 'Education' variables and the 'White' population, indicated in orange above.
# - There are low positive correlations between the health conditions and education levels. These correlation values are less than 0.2, indicated in blue above.
# - There is a negative correlation between 'Unemployment Rate' and 'Education level higher than Bachelors's Degree', evidenced by the negative correlation value darker blue color in the above heatmap.

# %% [markdown]
# #### Histograms

# %%
# Create an array with the colors 
colors = ["#0d00ff", "#ed7572"]
# Set color palette
sns.set_palette(sns.color_palette(colors))

# %%
plt.figure(figsize=(12,6))
df3.groupby('target_winner')['Median Earnings 2010'].plot(kind ='hist', bins=10, alpha = 0.5, title='Median Earnings 2010 distributions for winning party', legend =True,grid = True)
L=plt.legend()
L.get_texts()[0].set_text('Democratic Winner')
L.get_texts()[1].set_text('Republican Winner')
plt.xlabel("Median Earnings")
plt.show()

# %% [markdown]
# - The majority of counties that have Democratic winner have a median earning approximately between 21K and 25K.
# - The majority of counties that have Republican winner have a median earning approximately between 20K and 24K.
# - The lowest median income of counties with a Democratic winner is lower than that of the counties with a Republican winner.
# - Similarily, the highest median earning of the counties with a Democratic winner is also higher than that of the counties with a Republican winner.
# - This graph demonstrates a typical narrative of American politics: the average Republican voter is a wealthier White person living in a rural area, while the typical Democratic voter is more likely to live in a large, diverse city. It therefore also makes sense that there is a higher proportion of Republic winners in our graph; the counties won by Republicans are not as densely populated as those won by Democrats. It is important here to remember that this is not a representation of population but of individual counties.

# %%
plt.figure(figsize=(12,6))
df3.groupby('target_winner')['Median Age'].plot(kind ='hist', bins=10, alpha = 0.5, title='Median Age distributions for winning party', legend =True,grid = True)
L=plt.legend()
L.get_texts()[0].set_text('Democratic Winner')
L.get_texts()[1].set_text('Republican Winner')
plt.xlabel("Median Age")
plt.show()

# %% [markdown]
# - The majority of counties with a Democratic winner have a median age of between 34 and 40 years old.
# - The majority of counties with a Republican winner have a median age of between 38 and 42 years old.
# - The lowest median age of voters in counties with a Democratic winner is lower than the median age of counties with a Republican winner.
# - Conversely, the highest median age of counties with a Republican winner is higher than the median age of counties with a Democratic winner.
# - Again, this fits with the narrative in American politics that the older generation is more conservative and tends to vote Republican, while the younger generation tends to vote Democrat.

# %%
plt.figure(figsize=(12,6))
df3.groupby('target_winner')["At Least Bachelors's Degree"].plot(kind ='hist', bins=10, alpha = 0.5, title="At Least Bachelors's Degree distributions for winning party", legend =True,grid = True)
L=plt.legend()
L.get_texts()[0].set_text('Democratic Winner')
L.get_texts()[1].set_text('Republican Winner')
plt.xlabel("Percent of voters in county who have at Least Bachelors's Degree ")
plt.show()

# %% [markdown]
# - The majority of counties that have a Democratic winner have a percentage of voters with at least a Bachelors's degree between 20% and 30%.
# - The majority of counties that have a Republican winner have a lower percentage of voters with at least a Bachelors's degree, between 15% and 20%.
# - The distribution of the counties with a Republican winner are skewed right, which has a mean greater than the median and mode.
# - The highest percentage of the population with at least a Bachelors's degree in a county won by a Democrat is higher than that of the counties with a Republican winner.

# %%
plt.figure(figsize=(12,6))
df3.groupby('target_winner')["Unemployment"].plot(kind ='hist', bins=10, alpha = 0.5, title="Unemployment distributions for winning party", legend =True,grid = True)
L=plt.legend()
L.get_texts()[0].set_text('Democratic Winner')
L.get_texts()[1].set_text('Republican Winner')
plt.xlabel("Unemployment Rate")
plt.show()

# %% [markdown]
# - The majority of counties with a Democrat winner have an umemployment rate between 0.06 and 0.08, similar to the range in counties with a Republican winner.
# - The lowest unemployment rate in counties with a Republican winner is lower than the rate in counties where a Democrat won.

# %%
plt.figure(figsize=(12,6))
df3.groupby('target_winner')["Poverty.Rate.below.federal.poverty.threshold"].plot(kind ='hist', bins=10, alpha = 0.5, title="Poverty Rate below federal poverty threshold for winning party", legend =True,grid = True)
L=plt.legend()
L.get_texts()[0].set_text('Democratic Winner')
L.get_texts()[1].set_text('Republican Winner')
plt.xlabel("Poverty Rate below federal poverty threshold")
plt.show()

# %% [markdown]
# - The majority of counties with a Democratic winner have between 8% and 12% of their population below the poverty threshold.
# - Counties with a Republican winner have a higher percentage, between 12% and 15% of their population is below the poverty threshold.
# - The lowest poverty rate in counties with a Republican winner is lower than that of counties with a Democratic winner.

# %% [markdown]
# #### Scatter Plots

# %%
sns.set_palette(sns.color_palette(colors))
sns.lmplot("Median Earnings 2010", "At Least Bachelors's Degree", data =df3, fit_reg=True, aspect=1, height=6,hue='target_winner')
plt.show()

# %% [markdown]
# - For both Democratic winners and Republican winners, 'Median Earnings' and the 'At Least Bachelors's Degree' variables are positively correlated.
# - The median earnings increase as the percentage of population in the county with at least a Bachelors's degree increases.

# %%
sns.set_palette(sns.color_palette(colors))
sns.lmplot("Median Earnings 2010", 'Unemployment', data =df3, fit_reg=True, aspect=1, height=6,hue='target_winner')
plt.show()

# %% [markdown]
# - For both Democratic winners and Republican winners, the 'Median Earnings' and 'Unemployment Rate; variables have a negative correlation.
# - The median earnings increase as the unemployment rate decreases.

# %% [markdown]
# #### To further examine the relationship amonng features, we will use the pair grids

# %% [markdown]
# #### Pair Grids

# %%
selected_columns = ['Median Age', "At Least Bachelors's Degree", 'Homicide.rate', 'Poverty.Rate.below.federal.poverty.threshold','Unemployment', 'Violent.crime', 'target_winner']
subset =  df3[selected_columns]

# %%
graph = sns.PairGrid(subset, hue="target_winner")
graph = graph.map_diag(plt.hist) 
graph = graph.map_offdiag(plt.scatter) 
plt.legend(labels=['Democratic Winner', 'Republican Winter'])
plt.show()

# %% [markdown]
# - For both Democratic winners and Republican winners, the poverty rate and unemployment rate variables have a positive correlation. The poverty rate increases as the unemployment rate in the county increases.
# - Similarily, for both Democratic winners and Republican winners, the homicide rate and violent crime rate variables have a positive correlation.
# - For all counties, the 'At Least Bachelors's Degree' variable has a negative correlation with the homicide rate, poverty, and violence crime rate variables.

# %% [markdown]
# ### Split into Training, Validation, and Testing sets (with random seed of 4055)

# %%
X = df3.drop(['target_winner', 'State', 'ST', 'County'], axis=1)
y = df3["target_winner"]

# %%
random_seed=4055

# %%
class1 = (y == 1).sum()
class0 = (y == 0).sum()
print('Republican winners class 1: ',class1, "  Percent: " , (class1/3111)*100 )
print('Democrat winners class 0: ',class0, "    Percent: " , (class0/3111)*100)
# Out:
# Republican winners class 1:  2625   Percent:  84.37801350048217
# Democrat winners class 0:  486     Percent:  15.62198649951784

# %%
# split the datasets into training and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state = random_seed, test_size= 0.20)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, stratify=y_train, random_state = random_seed, test_size= 0.20)

# %%
cnt_train = y_train.value_counts()
per_train = y_train.value_counts(normalize=True)
cnt_val = y_val.value_counts()
per_val = y_val.value_counts(normalize=True)
cnt_test = y_test.value_counts()
per_test = y_test.value_counts(normalize=True)

pd.DataFrame({'Train_Count': cnt_train,'Val_Count': cnt_val, 'Test_Count': cnt_test, 'Train_Percent': per_train,'Val_Percent': per_val, 'Test_Percent': per_test})
# Out:
#    Train_Count  Val_Count  Test_Count  Train_Percent  Val_Percent  \
# 1         1679        420         526       0.843719     0.843373
# 0          311         78          97       0.156281     0.156627
#
#    Test_Percent
# 1      0.844302
# 0      0.155698

# %% [markdown]
# ### We will use training and validation sets in model fitting and model comparison and keep the test set for evaluating and selecting the best model.

# %% [markdown]
# ### Standarized Data

# %%
ss = preprocessing.StandardScaler()
X_ss = ss.fit_transform(X_train).tolist()
X_val_ss = ss.fit_transform(X_val).tolist()
X_test_ss = ss.fit_transform(X_test).tolist()
skf = StratifiedKFold(n_splits=5, random_state=random_seed)
skf.get_n_splits(X_ss, y_train)
# Out:
# 5

# %% [markdown]
# ## <font color = blue> Machine Learning Models

# %% [markdown]
# - Our team built models with 5 Machine Learning algorithms, including Decision Tree, Logistic Regression, Random Forest, KNN, and SVC.
# - The details of models can be found in the section below.

# %% [markdown]
# ## Part 1- Decision Tree

# %%
# Import DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
def computeAccuracy(myY_true, myY_pred):
    return metrics.accuracy_score(y_true = myY_true, y_pred = myY_pred)

# %%
def showMetrics(myTitle, myY_true, myY_pred):
    confusion_matrix =  pd.crosstab(index=np.ravel(myY_true), columns=myY_pred.ravel(), rownames=['Actual'], colnames=['Predicted'])
    sns.heatmap(confusion_matrix, annot=True, square=False, fmt='', cbar=False)
    plt.title(myTitle, fontsize = 15)
    plt.show()
    print(metrics.classification_report(y_true = myY_true, y_pred = myY_pred))

# %%
def plotValues(myTitle, myLabelX, myScores, myXList):
    plt.figure(figsize=(10,5))
    plt.title(myTitle)
    plt.plot(myScores, 'go--',label = 'validation')
    plt.xticks(np.arange(len(myXList)), myXList, rotation = 45)
    plt.xlabel(myLabelX)
    plt.ylabel('Accuracy Scores')
    plt.legend()
    plt.show()

# %% [markdown]
# ### 1.1 Default Model

# %%
dt = DecisionTreeClassifier(random_state=random_seed)
dt.fit(X_train, y_train)

pred_train = dt.predict(X_train)
pred_val = dt.predict(X_val)

#Accuracy Train
print("Accuracy Scores (Train): ",computeAccuracy(y_train, pred_train))

#Accuracy Val
print("Accuracy Scores (Validation): ",computeAccuracy(y_val, pred_val))
# Out:
# Accuracy Scores (Train):  1.0
# Accuracy Scores (Validation):  0.9317269076305221

# %%
showMetrics("Confusion Matrix for Default Decision Tree", y_val, pred_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78        78
#            1       0.96      0.96      0.96       420
#
#     accuracy                           0.93       498
#    macro avg       0.87      0.87      0.87       498
# weighted avg       0.93      0.93      0.93       498

# %% [markdown]
# - The default model is overfitting as the accuracy rate of train and validation set are 7% apart and are close to each other.
# - The specificity is significantly lower than recall and precision, so the model can't predict and explain class 0 as good as class 1.
# - We will preform the hyperparameter tuning and Gridsearch CV to find the best params for Decision Tree

# %% [markdown]
# ### 1.2 Find the best value of minimum splits

# %%
MS_list = [10, 30, 50, 100, 150, 200, 300, 400, 500]
accuracy_valid = []
for ms in MS_list:
    dt = DecisionTreeClassifier(min_samples_split= ms, random_state = 42)
    dt.fit(X_train, y_train)
    pred_train = dt.predict(X_train)
    score_valid= cross_val_score(dt,X_train, y_train, scoring = "accuracy", cv =5 )
    accuracy_valid.append(score_valid.mean())
print("Accuracy score: ")
accuracy_valid
# Out:
# Accuracy score:
# [0.9527638190954774,
#  0.9552763819095478,
#  0.956281407035176,
#  0.9527638190954774,
#  0.9371859296482411,
#  0.9246231155778893,
#  0.9231155778894472,
#  0.9246231155778896,
#  0.9246231155778896]

# %%
plotValues("The Validation Curve of 5-fold Decision Tree", 'Min Samples Split Values', accuracy_valid, MS_list )

# %% [markdown]
# - The best min split is 50, so will will carry this value over to the next step

# %% [markdown]
# ### 1.2 GridSearchCV

# %% [markdown]
# To improve the performance, we can compute the class_weight using the sklearn.utils
# Then, we will specify different class_weights in params for gridSerach so that the higher class-weight means you want to put more emphasis on a class. We will put more weight on the class 0 relative to class 1

# %%
# Compute class_weights
from sklearn.utils import class_weight
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)
print(class_weights)
# Out:
# [3.19935691 0.59261465]

# %%
MS_list = [50] #from part 1.2
MD_list = [2, 3, 5, 7, 10]
criterion_list = ['gini', 'entropy']
CW_list = [{ 0:1, 1: 1},{0:1.5, 1:1},{0:2, 1:1}, {0:3, 1:0.5} ]

params = {"criterion": criterion_list, 'min_samples_split': MS_list,"class_weight": CW_list,
         'max_depth': MD_list, 'random_state': [54]}
dt = DecisionTreeClassifier()
grid_dt = GridSearchCV(estimator=dt, param_grid=params, cv=5, verbose =1, scoring="balanced_accuracy", n_jobs=-1)

# %%
grid_dt.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    2.8s finished
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'class_weight': [{0: 1, 1: 1}, {0: 1.5, 1: 1},
#                                           {0: 2, 1: 1}, {0: 3, 1: 0.5}],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 5, 7, 10],
#                          'min_samples_split': [50], 'random_state': [54]},
#              scoring='balanced_accuracy', verbose=1)

# %%
print(grid_dt.best_params_)
print(grid_dt.best_estimator_)
# Out:
# {'class_weight': {0: 2, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 50, 'random_state': 54}
# DecisionTreeClassifier(class_weight={0: 2, 1: 1}, criterion='entropy',
#                        max_depth=5, min_samples_split=50, random_state=54)

# %% [markdown]
# #### Fit the GridSearch Model

# %%
dt_gs = DecisionTreeClassifier(class_weight={0: 2, 1: 1}, criterion='entropy',
                       max_depth=5, min_samples_split=50, random_state=54)
dt_gs.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight={0: 2, 1: 1}, criterion='entropy',
#                        max_depth=5, min_samples_split=50, random_state=54)

# %% [markdown]
# #### Compute the Accuracy rates

# %%
pred_train = dt_gs.predict(X_train)
pred_val = dt_gs.predict(X_val)

#Accuracy Train
print("Accuracy Scores (Train): ",computeAccuracy(y_train, pred_train))

#Accuracy Val
print("Accuracy Scores (Validation): ",computeAccuracy(y_val, pred_val))
# Out:
# Accuracy Scores (Train):  0.964824120603015
# Accuracy Scores (Validation):  0.9437751004016064

# %%
showMetrics("Confusion Matrix for GridSearch Decision Tree", y_val, pred_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84        78
#            1       0.99      0.95      0.97       420
#
#     accuracy                           0.94       498
#    macro avg       0.88      0.94      0.90       498
# weighted avg       0.95      0.94      0.95       498

# %% [markdown]
# #### Decision Tree Comparison (Default Model vs GridSearchCV Model)

# %% [markdown]
# - The best model has higher accuracy and precision. The weighted avg accuracy, precision, recall, and f1 are also higher than the default model, so it performs better than the default model.
# - The obvious improvement is that the GridSearchCV model can predict both class 0 (minority) and class 1(majority) well as we specify the class weight and use the balanced accuracy score in GridSearchCV.
# - Comparing to the default model, the best model is less overfitting as the accuracy rate of train and test set are high and close to each other.

# %%
from sklearn import tree
fn = X_train.columns
cn = ['Demecrats','Republican']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (30,20), dpi=200)
tree.plot_tree(dt_gs,feature_names = fn, class_names=cn, filled = True, fontsize=12);

# %% [markdown]
# - Based on the decision tree classifier, we can conclude that The most important variables to predicting the outcome of an election are the winning result from the previous election in year 2012.
# - Additionally, the median age and race features play important roles on the voters' preferences on a political party.
# - We can derive the clssification rules as follow: if the median age of the voters in the county is less than 38.15 years old, it is likely that the democatic candidate will win the election for that county.
# - Additionally, if the county has the percentage of Asian American voters less than 2.5%, the democatic candidate will be likely to win the election. On the other hand, if the percentage of White voters are less than 47%, the Republican candidate has a high chance to win the election.
# - The education level also play an important role in which if the percentage of voters in the county who has at keast bachelor's degree is less than 18%, the Republican candidate is likely to win the election for that county.

# %% [markdown]
# ### 1.3  Ten Important Features from Decision Tree

# %%
imp = dt_gs.feature_importances_
feat_importances = pd.Series(imp, index=X_train.columns)
feat_importances.nlargest(10)
# Out:
# 2012 winner                                                  0.763278
# Median Age                                                   0.049564
# Total Population                                             0.036021
# White (Not Latino) Population                                0.033787
# Production.transportation.and.material.moving.occupations    0.031306
# At Least Bachelors's Degree                                  0.027164
# Asian American Population                                    0.022871
# Uninsured                                                    0.012501
# School Enrollment                                            0.011986
# Latino Population                                            0.006184
# dtype: float64

# %%
colors = ["#059e5c"]
# Set color palette
sns.set_palette(sns.color_palette(colors))
plt.figure(figsize=(12,6))
feat_importances.nlargest(10).plot(kind='barh')
plt.title("Top 10 important features")
plt.show()

# %% [markdown]
# - From the best Decision Tree in part 1.2, we can answer the research questions by identifying that the "2012 winner" variable is the most important feature which is located at the root node.
# - The second most important feature is the "Median Age".
# - Other demographic features such as race, specific occupations, and education level features also have a high influence on the target variable.
# - Comparing to the health condition and surrounding factors, the demographic features such as race and education level have more influence on election winner.

# %% [markdown]
# ## Part 2 - Logistic Regression

# %%
# Import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score,recall_score, roc_auc_score, roc_curve
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV

# %%
def evaluate_results(test, train, train_target, test_target, model):
    '''This function will print evaluation metrics'''
    
    pred_test = model.predict(test)
    
    probs_test = model.predict_proba(test)[:, 1]
    probs_train = model.predict_proba(train)[:, 1]
    
    print()
    print('Test Accuracy = {0:.4f}'.format(model.score(test, test_target)))
    print('Train Accuracy = {0:.4f}'.format(model.score(train, train_target)))
    print()
    print('Train ROC AUC Score: {0:.4f}'.format(roc_auc_score(train_target, probs_train)))
    print('Test ROC AUC  Score: {0:.4f}'.format(roc_auc_score(test_target, probs_test)))
    print()
    print('Test Recall: {0:.4f}'.format(recall_score(test_target, pred_test)))
    print('Test Precision: {0:.4f}'.format(precision_score(test_target, pred_test)))
    print()
    
    fpr, tpr, _ = roc_curve(test_target,  probs_test)
    auc = roc_auc_score(test_target, probs_test)
 
    plt.plot(fpr,tpr,label="auc="+str(auc))
    plt.plot([0, 1], [0, 1],'r--')
    plt.legend(loc=4)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves');
    plt.show()

# %%
def plot_coeff(model, test_data):
    coef_dict = {}
    for coef, feat in zip(model.coef_[0,:], test_data):
        coef_dict[feat] = coef    
    # sorted dict    
    {k: v for k, v in sorted(coef_dict.items(), reverse=True, key=lambda item: item[1])}
    
    coeff_df = pd.DataFrame(coef_dict.items(), index = coef_dict.keys())
    print()
    print(coeff_df.iloc[:,1])
    coeff_df[0:].plot(kind = 'barh', 
                      figsize = (10,10),
                      title = 'Coefficients')

# %% [markdown]
# ### 2.1 - Initial Model

# %%
# initiate the classifier
base_clf = LogisticRegression(random_state = random_seed)

# fit the model
base_clf.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=4055)

# %%
# evaluate results
evaluate_results(X_val, X_train, y_train, y_val, base_clf)
# Out:
# Test Accuracy = 0.8855
# Train Accuracy = 0.9005
#
# Train ROC AUC Score: 0.8953
# Test ROC AUC  Score: 0.8566
#
# Test Recall: 0.9833
# Test Precision: 0.8920

# %%
# confusion Matrix
disp = plot_confusion_matrix(base_clf, 
                             X_val, y_val,
                             display_labels=['Democrat','Republican'],
                             values_format= '.0f',
                             cmap=plt.cm.Blues)

# %%
# display metrics
test_pred = base_clf.predict(X_val)
print(classification_report(y_val, test_pred))
print('Balanced Accuracy =', round(metrics.balanced_accuracy_score(y_val, test_pred),2))
print('Specificity = ',round(1 - metrics.recall_score(y_val, test_pred),2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.36      0.50        78
#            1       0.89      0.98      0.94       420
#
#     accuracy                           0.89       498
#    macro avg       0.85      0.67      0.72       498
# weighted avg       0.88      0.89      0.87       498
#
# Balanced Accuracy = 0.67
# Specificity =  0.02

# %% [markdown]
# -----

# %% [markdown]
# You can see from the results above that the generic model performed quite well with a 89% accuracy, but low specificity, so we will perform hyper parameter tuning. Based on the AUC, Balanced and ROC curve, I can see the model is balanced out nicely with and performing well in terms of FP, FN, TP, TN.

# %% [markdown]
# -----

# %% [markdown]
# ### 2.2 Hyper-parameter tuning

# %% [markdown]
# #### Perform Randomized Search

# %%
# Hyperparameter grid for randomized search
param_grid = {
    'solver': ['lbfgs','liblinear','sag','saga'],
    'penalty': ['l1','l2'],
    'tol': list(np.arange(.00001,.1, .005).astype(float)),
    'C': list(np.arange(.0001,.1, .007).astype(float)),
}

# Estimator for use in random search
estimator = LogisticRegression(random_state = random_seed)

# Create the random search model
rs = RandomizedSearchCV(estimator, param_grid, n_jobs = -1, 
                        cv = 10, n_iter = 10, verbose = 1, random_state=random_seed)

# Fit 100 different models to search for optimal params
rs.fit(X_train, np.ravel(y_train))

# Get the best parameters
rs.best_params_
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  93 out of 100 | elapsed:    1.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    1.1s finished
# {'tol': 0.02001,
#  'solver': 'liblinear',
#  'penalty': 'l1',
#  'C': 0.08410000000000001}

# %% [markdown]
# #### Grid Search

# %%
# now perform grid search with all parameters selected intelligently 
param_grid = {
    'tol': list(np.arange(.007,.13, .01).astype(float)),
    'C': list(np.arange(.04,.14, .01).astype(float))
}

# search through the grid
tuned_lr = LogisticRegression(solver = 'liblinear', penalty = 'l1', random_state = random_seed)

gs = GridSearchCV(tuned_lr, param_grid, verbose=1, cv=5, n_jobs = -1)
gs.fit(X_train, np.ravel(y_train))
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Fitting 5 folds for each of 130 candidates, totalling 650 fits
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 650 out of 650 | elapsed:    2.5s finished
# GridSearchCV(cv=5,
#              estimator=LogisticRegression(penalty='l1', random_state=4055,
#                                           solver='liblinear'),
#              n_jobs=-1,
#              param_grid={'C': [0.04, 0.05, 0.060000000000000005, 0.07,
#                                0.08000000000000002, 0.09000000000000001, 0.1,
#                                0.11000000000000001, 0.12000000000000002,
#                                0.13000000000000003],
#                          'tol': [0.007, 0.017, 0.027000000000000003,
#                                  0.037000000000000005, 0.04700000000000001,
#                                  0.05700000000000001, 0.06700000000000002,
#                                  0.07700000000000001, 0.08700000000000002,
#                                  0.09700000000000003, 0.10700000000000003,
#                                  0.11700000000000002, 0.12700000000000003]},
#              verbose=1)

# %%
# look at best values
print('Best parameters:', gs.best_params_ )
print('Best Score:', gs.best_score_)
# Out:
# Best parameters: {'C': 0.12000000000000002, 'tol': 0.007}
# Best Score: 0.9663316582914574

# %% [markdown]
# -----

# %% [markdown]
# The first step of parameter tuning was to perform randomized search. This allowed me to narrow the window for grid search. I do this so that I can hone in on a specific range of parameters to tune. The next step is to perform the actual grid search. The two main parameters to tune were 'C', which is the inverse of regularization strength, and 'tol' which stands for tolerance. I also found that the best model used a liblinear solver and favored l1 regularization of l2.

# %% [markdown]
# -----

# %% [markdown]
# ### 2.3 - Evaluate Best Fit Model

# %%
# Tuned model
tuned_lr = LogisticRegression(solver = 'liblinear', 
                              penalty = 'l1', 
                              C = .06,
                              tol = .007,
                              random_state = random_seed)

# fit the model
tuned_lr.fit(X_train, y_train)

# evaluate results
evaluate_results(X_val, X_train, y_train, y_val, tuned_lr)
# Out:
# Test Accuracy = 0.9679
# Train Accuracy = 0.9698
#
# Train ROC AUC Score: 0.9937
# Test ROC AUC  Score: 0.9918
#
# Test Recall: 0.9810
# Test Precision: 0.9810

# %%
# display metrics
test_pred = tuned_lr.predict(X_val)
print(classification_report(y_val, test_pred))
print('Balanced Accuracy =', round(metrics.balanced_accuracy_score(y_val, test_pred),2))
print('Specificity = ',round(1 - metrics.recall_score(y_val, test_pred),2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        78
#            1       0.98      0.98      0.98       420
#
#     accuracy                           0.97       498
#    macro avg       0.94      0.94      0.94       498
# weighted avg       0.97      0.97      0.97       498
#
# Balanced Accuracy = 0.94
# Specificity =  0.02

# %% [markdown]
# #### A plot of probabilities

# %%
test_probs = tuned_lr.predict_proba(X_val)

Democrat = list(test_probs[:,0])
Republican = list(test_probs[:,1])

plt.figure(figsize = (10,10))
plt.hist(Democrat, 
              color = 'red', 
              edgecolor = 'black', 
              bins = 20,
              alpha = .4,
              label = 'Democrat')

plt.hist(Republican, 
              color = 'blue', 
              edgecolor = 'black', 
              bins = 20,
              alpha = .4,
              label = 'Republican')
plt.legend(loc = 'upper center')
plt.xticks(np.arange(0, 1, step=0.1))
plt.xlabel('Prob')
plt.ylabel('Freq')
plt.title('Test Probabilities')
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# We can see that I was able to improve the accuracy and specificity to 97% and 90%, respectively. We managed to improve the other evaluation metrics as well and nearly are able to perfectly predict which party will win in that county.
#
# The purpose of the probability plot is to evaluate at the percentage level how the model is predicting each class. Our model is very good, but what I am looking for is a nice U shape like this plot. If I were to see a spike around the 50% probability tick, then we would have a frequency count of the amount of time our model is no better than a coin flip.

# %% [markdown]
# ----

# %% [markdown]
# ### 2.4 - Coefficients and Feature Exploration

# %%
plot_coeff(tuned_lr, X_val)
# Out:
# Less Than High School Diploma                                 1.802382e-02
# At Least High School Diploma                                  5.005692e-03
# At Least Bachelors's Degree                                  -1.058866e-01
# Graduate Degree                                              -1.032859e-01
# School Enrollment                                             7.170733e-03
# Median Earnings 2010                                          1.654077e-05
# White (Not Latino) Population                                 2.947712e-02
# African American Population                                  -5.241313e-02
# Native American Population                                   -1.829049e-02
# Asian American Population                                    -8.308831e-02
# Other Race or Races                                           0.000000e+00
# Latino Population                                            -2.977296e-02
# Children Under 6 Living in Poverty                            1.019915e-02
# Adults 65 and Older Living in Poverty                        -2.971509e-02
# Total Population                                             -6.583091e-07
# Preschool.Enrollment.Ratio.enrolled.ages.3.and.4             -2.344717e-03
# Poverty.Rate.below.federal.poverty.threshold                  0.000000e+00
# Child.Poverty.living.in.families.below.the.poverty.line      -1.057757e-02
# Management.professional.and.related.occupations               1.676898e-02
# Service.occupations                                          -1.807750e-02
# Sales.and.office.occupations                                  0.000000e+00
# Farming.fishing.and.forestry.occupations                      0.000000e+00
# Construction.extraction.maintenance.and.repair.occupations    0.000000e+00
# Production.transportation.and.material.moving.occupations     3.556500e-02
# Sire Homogeneity                                              0.000000e+00
# Median Age                                                    0.000000e+00
# Poor.physical.health.days                                     0.000000e+00
# Poor.mental.health.days                                       0.000000e+00
# Low.birthweight                                               0.000000e+00
# Teen.births                                                   6.571520e-03
# Children.in.single.parent.households                          0.000000e+00
# Adult.smoking                                                 0.000000e+00
# Adult.obesity                                                 0.000000e+00
# Diabetes                                                      0.000000e+00
# Sexually.transmitted.infections                              -3.075589e-04
# HIV.prevalence.rate                                           1.075424e-03
# Uninsured                                                     0.000000e+00
# Unemployment                                                  0.000000e+00
# Violent.crime                                                -7.550767e-04
# Homicide.rate                                                -4.013576e-02
# Injury.deaths                                                 3.532719e-03
# Infant.mortality                                              0.000000e+00
# 2008 winner                                                   1.723129e+00
# 2012 winner                                                   2.416870e+00
# Name: 1, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# We can see from above that because this model used l1 regularization, we actually pushed quite a few coefficients to 0. This would mean that these can be removed from the model entirely. We actually reduce the number of features from 48 to 17.
#
# Because our data is scaled, we could in turn say that the 3 most significant features for logistic regression are:
#  - At least a Bachelor's Degree
#  - Party choice (election winner) in 2008
#  - Party choice (election winner) in 2012

# %% [markdown]
# ---

# %% [markdown]
# ## Part 3 - Random Forest

# %%
#importing random forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, recall_score, precision_score, f1_score, balanced_accuracy_score
from sklearn.metrics import classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV

# %%
#creating a function that will spit out key metrics I want to evaluate from my model
def evaluation_metrics(X_train, X_test, y_train, y_test, model):
    'This will produce and print the evaluation metrics for each model'
    
    pred_test = model.predict(X_test)
    
    print('Training Accuracy = {0:.3f}'.format(model.score(X_train, y_train)))
    print('Validation Accuracy = {0:.3f}'.format(model.score(X_test, y_test)))
    print('Recall = {0:.3f}'.format(recall_score(y_test, pred_test)))
    print('Precision = {0:.3f}'.format(precision_score(y_test, pred_test)))
    print('Balanced Accuracy = {0:.3f}'.format(balanced_accuracy_score(y_test, pred_test)))
    print('F1 Score = {0:.3f}'.format(f1_score(y_test, pred_test)))
    print()
    print('Confusion Matrix:')
    print(confusion_matrix(y_test, pred_test))

# %%
def plot_coeff(model, test_data):
    coef_dict = {}
    for coef, feat in zip(model.coef_[0,:], test_data):
        coef_dict[feat] = coef    
    # sorted dict    
    {k: v for k, v in sorted(coef_dict.items(), reverse=True, key=lambda item: item[1])}
    
    coeff_df = pd.DataFrame(coef_dict.items(), index = coef_dict.keys())
    print()
    print(coeff_df.iloc[:,1])
    coeff_df[0:].plot(kind = 'barh', 
                      figsize = (10,10),
                      title = 'Coefficients')

# %% [markdown]
# ### 3.1 - Initial Model

# %%
rf = RandomForestClassifier(random_state=random_seed)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=4055)

# %%
evaluation_metrics(X_train, X_val, y_train, y_val, rf)
# Out:
# Training Accuracy = 1.000
# Validation Accuracy = 0.966
# Recall = 0.986
# Precision = 0.974
# Balanced Accuracy = 0.922
# F1 Score = 0.980
#
# Confusion Matrix:
# [[ 67  11]
#  [  6 414]]

# %%
# confusion Matrix
disp = plot_confusion_matrix(rf, 
                             X_test, y_test,
                             display_labels=['Democrat','Republican'],
                             values_format= '.0f',
                             cmap=plt.cm.Blues)

# %% [markdown]
# - Based on the running of my model just using the default value it is looking really good at predicting the  winner in the county.
# - With training and validation accuracy scores coming in at 100% and 96.5% respectivly we are doing really well
# - The recall and F1 score are both over 97% whick is another strong indicator.

# %% [markdown]
# ### 3.2 Hyper-parameter tuning

# %%
# Hyperparameter grid for randomized search
parameters= {'criterion':['gini', 'entropy'],'min_samples_split':[10,25,50,100,250,500,1000] ,
            'max_depth':[3,5,7,10,25,50,100],
            'n_estimators':[5,10,25,25,50], 'max_features':['auto', 'sqrt', 'log2']}

# Estimator for use in random search
estimator = RandomForestClassifier(random_state = random_seed)

# Create the random search model
rs = RandomizedSearchCV(estimator, parameters, n_jobs = -1, 
                        cv = 10, n_iter = 10, verbose = 1, random_state=random_seed)

# Fit 100 different models to search for optimal params
rs.fit(X_train, np.ravel(y_train))

# Get the best parameters
rs.best_params_
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done  93 out of 100 | elapsed:    3.3s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    3.6s finished
# {'n_estimators': 25,
#  'min_samples_split': 10,
#  'max_features': 'auto',
#  'max_depth': 10,
#  'criterion': 'entropy'}

# %% [markdown]
# ### Grid Search

# %%
#creating parameters for creating the random forest
parameters={"min_samples_split":[10,25,50,100,250,500,1000] ,
            'max_depth':[3,5,7,10,25,50,100],
            'n_estimators':[5,10,25,25,50]}

# %%
tuned_rf = RandomForestClassifier(criterion= 'entropy' ,max_features= 'auto',random_state = random_seed)

# %%
RFgrid_cv=GridSearchCV(estimator=tuned_rf,param_grid= parameters, cv= 5,scoring = 'recall')

# %%
#fitting the grid and preforming the CV search to get scores for all combinations
RFgrid_cv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(criterion='entropy',
#                                               random_state=4055),
#              param_grid={'max_depth': [3, 5, 7, 10, 25, 50, 100],
#                          'min_samples_split': [10, 25, 50, 100, 250, 500, 1000],
#                          'n_estimators': [5, 10, 25, 25, 50]},
#              scoring='recall')

# %%
#returning the best combination of my parameters
RFgrid_cv.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=3, min_samples_split=1000,
#                        n_estimators=5, random_state=4055)

# %% [markdown]
# ### 3.3 - Evaluate Best Fit Model

# %%
final_RF=RandomForestClassifier(criterion= 'entropy' ,max_features= 'auto',max_depth=3, min_samples_split=1000
                                ,n_estimators=5,random_state = random_seed)
final_RF=final_RF.fit(X_train,y_train)

# %%
evaluation_metrics(X_train, X_val, y_train, y_val, final_RF)
# Out:
# Training Accuracy = 0.909
# Validation Accuracy = 0.884
# Recall = 0.998
# Precision = 0.880
# Balanced Accuracy = 0.633
# F1 Score = 0.935
#
# Confusion Matrix:
# [[ 21  57]
#  [  1 419]]

# %%
# confusion Matrix
disp = plot_confusion_matrix(final_RF, 
                             X_val, y_val,
                             display_labels=['Democrat','Republican'],
                             values_format= '.0f',
                             cmap=plt.cm.Blues)

# %% [markdown]
# - Both my validation and training accuracy went down when optimizing the model
# - That said my tresting and training accuracy is now closer at 91.1 and 90.5 making this slightly better
# - Also in the tuning I was able to better my confussion matix values

# %% [markdown]
# ### 3.4 - Coefficients and Feature Exploration

# %%
#getting information on scorring of importacne of features in the model
rf_feat = final_RF.feature_importances_
rf_feat_importances = pd.Series(rf_feat, index=X_train.columns)
rf_feat_importances
# Out:
# Less Than High School Diploma                                 0.000000
# At Least High School Diploma                                  0.000000
# At Least Bachelors's Degree                                   0.101894
# Graduate Degree                                               0.000000
# School Enrollment                                             0.000000
# Median Earnings 2010                                          0.000000
# White (Not Latino) Population                                 0.236000
# African American Population                                   0.000000
# Native American Population                                    0.000000
# Asian American Population                                     0.000000
# Other Race or Races                                           0.000000
# Latino Population                                             0.000000
# Children Under 6 Living in Poverty                            0.000000
# Adults 65 and Older Living in Poverty                         0.000000
# Total Population                                              0.000000
# Preschool.Enrollment.Ratio.enrolled.ages.3.and.4              0.000000
# Poverty.Rate.below.federal.poverty.threshold                  0.079554
# Child.Poverty.living.in.families.below.the.poverty.line       0.000000
# Management.professional.and.related.occupations               0.000000
# Service.occupations                                           0.047778
# Sales.and.office.occupations                                  0.000000
# Farming.fishing.and.forestry.occupations                      0.000000
# Construction.extraction.maintenance.and.repair.occupations    0.334775
# Production.transportation.and.material.moving.occupations     0.000000
# Sire Homogeneity                                              0.000000
# Median Age                                                    0.000000
# Poor.physical.health.days                                     0.000000
# Poor.mental.health.days                                       0.000000
# Low.birthweight                                               0.000000
# Teen.births                                                   0.000000
# Children.in.single.parent.households                          0.000000
# Adult.smoking                                                 0.000000
# Adult.obesity                                                 0.000000
# Diabetes                                                      0.000000
# Sexually.transmitted.infections                               0.000000
# HIV.prevalence.rate                                           0.000000
# Uninsured                                                     0.000000
# Unemployment                                                  0.000000
# Violent.crime                                                 0.000000
# Homicide.rate                                                 0.000000
# Injury.deaths                                                 0.000000
# Infant.mortality                                              0.000000
# 2008 winner                                                   0.000000
# 2012 winner                                                   0.200000
# dtype: float64

# %%
#ploting top 10 important features
colors = ["#059e5c"]
# Set color palette
sns.set_palette(sns.color_palette(colors))
plt.figure(figsize=(12,6))
rf_feat_importances.nlargest(10).plot(kind='barh')
plt.title("Top 15 important features")
plt.show()

# %% [markdown]
# From the best Random Forest, we can answer the research questions by identifying that the construction occupation of voters, race, and  "2012 winner" variable are the most important features.
# Other demographic features such as race, specific occupations, and education level features also have a high influence on the target variable.
# Comparing to the surrounding factors, the demographic features such as race and education level have more influence on election winner.

# %% [markdown]
# ## Part 4 - K-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, plot_confusion_matrix
from sklearn import neighbors
from sklearn.inspection import permutation_importance
from matplotlib.colors import ListedColormap

# %%
def evaluation_metrics(X_train, X_test, y_train, y_test, model):
    'This will produce and print the evaluation metrics for each model'
    
    pred_test = model.predict(X_test)
    
    print('Training Accuracy = {0:.3f}'.format(model.score(X_train, y_train)))
    print('Validation Accuracy = {0:.3f}'.format(model.score(X_test, y_test)))
    print('Recall = {0:.3f}'.format(recall_score(y_test, pred_test)))
    print('Precision = {0:.3f}'.format(precision_score(y_test, pred_test)))
    print('Balanced Accuracy = {0:.3f}'.format(balanced_accuracy_score(y_test, pred_test)))
    print('F1 Score = {0:.3f}'.format(f1_score(y_test, pred_test)))
    print()
    print('Confusion Matrix:')
    print(confusion_matrix(y_test, pred_test))

# %%
X_train_ss = X_ss

# %% [markdown]
# ### 4.1 Find Ideal Number of Neighbors

# %%
K_list = [1,3,5,7,9,15,19,25,29,35,39,45,49,99]
accuracy_train_ss = []
accuracy_val_ss = []
for K in K_list:
    clf = KNeighborsClassifier(n_neighbors=K)
    clf.fit(X_train_ss, y_train) # fit the model
    
    pred_train_ss = clf.predict(X_train_ss) # training predictions
    accuracy_train_ss.append(metrics.accuracy_score(y_true = y_train, y_pred = pred_train_ss)) 
    
    pred_val_ss = clf.predict(X_val_ss) # val predictions
    accuracy_val_ss.append(metrics.accuracy_score(y_true = y_val, y_pred = pred_val_ss))

# %%
accuracy_train_ss
# Out:
# [1.0,
#  0.9798994974874372,
#  0.9793969849246231,
#  0.971356783919598,
#  0.9688442211055276,
#  0.964321608040201,
#  0.964824120603015,
#  0.9623115577889447,
#  0.9633165829145729,
#  0.9547738693467337,
#  0.9512562814070352,
#  0.9507537688442211,
#  0.9487437185929648,
#  0.9236180904522613]

# %%
accuracy_val_ss
# Out:
# [0.9538152610441767,
#  0.9578313253012049,
#  0.9618473895582329,
#  0.9518072289156626,
#  0.9457831325301205,
#  0.9457831325301205,
#  0.9457831325301205,
#  0.9497991967871486,
#  0.9437751004016064,
#  0.9397590361445783,
#  0.9377510040160643,
#  0.9357429718875502,
#  0.9417670682730924,
#  0.9257028112449799]

# %%
plt.figure(figsize=(10,6))
plt.plot(K_list, accuracy_train_ss, label='Train')
plt.plot(K_list, accuracy_val_ss, label='Validation')
plt.xlabel('K Values')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# The validation accuracy peaks at 97.27%, which corresponds to a K-value of 35.

# %% [markdown]
# #### With K = 35 Neighbors

# %%
neigh = KNeighborsClassifier(n_neighbors=35)
neigh.fit(X_train_ss, y_train)
pred_train_ss = neigh.predict(X_train_ss)
print("Accuracy Train: ", metrics.accuracy_score(y_true = y_train, y_pred = pred_train_ss))
pred_val_ss = neigh.predict(X_val_ss)
print("Accuracy Validation: ", metrics.accuracy_score(y_true = y_val, y_pred = pred_val_ss))
print(metrics.classification_report(y_true = y_val, y_pred = pred_val_ss))
# Out:
# Accuracy Train:  0.9547738693467337
# Accuracy Validation:  0.9397590361445783
#               precision    recall  f1-score   support
#
#            0       0.89      0.71      0.79        78
#            1       0.95      0.98      0.96       420
#
#     accuracy                           0.94       498
#    macro avg       0.92      0.84      0.88       498
# weighted avg       0.94      0.94      0.94       498

# %% [markdown]
# #### Confusion Matrix

# %%
disp = plot_confusion_matrix(neigh, 
                             X_test_ss, y_test,
                             display_labels=['Democrat','Republican'],
                             values_format= '.0f',
                             cmap=plt.cm.Blues)

# %%
evaluation_metrics(X_train_ss, X_val_ss, y_train, y_val, neigh)
# Out:
# Training Accuracy = 0.955
# Validation Accuracy = 0.940
# Recall = 0.983
# Precision = 0.947
# Balanced Accuracy = 0.844
# F1 Score = 0.965
#
# Confusion Matrix:
# [[ 55  23]
#  [  7 413]]

# %% [markdown]
# - Overall, KNN is performing quite well. High accuracy, F1, Recall, and Precision rates over 94%.
# - The gap between the training and validation accuracy scores is small so the model is not overfitting.
# - However, one disadvantage of KNN is that it does not support feature selection, therefore it is challenging to gain insight into the algorithm.
# - To understand feature importance, I will use permutation feature importance from sklearn.inspection.

# %% [markdown]
# ### Feature Importance using permutation_importance

# %%
results = permutation_importance(neigh, X_test_ss, y_test, scoring='accuracy')

# %%
importance = results.importances_mean
feat_importances = pd.Series(importance, index=X_test.columns)
feat_importances.sort_values(ascending=False)
# Out:
# 2012 winner                                                   0.034350
# 2008 winner                                                   0.028250
# African American Population                                   0.007384
# Children.in.single.parent.households                          0.007384
# At Least Bachelors's Degree                                   0.006421
# White (Not Latino) Population                                 0.005136
# Graduate Degree                                               0.003852
# Adults 65 and Older Living in Poverty                         0.003852
# Infant.mortality                                              0.003531
# Unemployment                                                  0.003531
# Latino Population                                             0.003210
# Adult.obesity                                                 0.003210
# Children Under 6 Living in Poverty                            0.002568
# HIV.prevalence.rate                                           0.002568
# Asian American Population                                     0.002568
# Diabetes                                                      0.002247
# Construction.extraction.maintenance.and.repair.occupations    0.002247
# Service.occupations                                           0.001926
# Low.birthweight                                               0.001926
# Child.Poverty.living.in.families.below.the.poverty.line       0.001605
# Poor.mental.health.days                                       0.001284
# Native American Population                                    0.000642
# Management.professional.and.related.occupations               0.000642
# Less Than High School Diploma                                 0.000642
# Adult.smoking                                                 0.000642
# Sexually.transmitted.infections                               0.000642
# Poor.physical.health.days                                     0.000321
# At Least High School Diploma                                  0.000321
# Preschool.Enrollment.Ratio.enrolled.ages.3.and.4              0.000321
# Poverty.Rate.below.federal.poverty.threshold                  0.000000
# Violent.crime                                                -0.000321
# Farming.fishing.and.forestry.occupations                     -0.000321
# Teen.births                                                  -0.000321
# Median Age                                                   -0.000321
# Other Race or Races                                          -0.000642
# Sire Homogeneity                                             -0.000963
# Sales.and.office.occupations                                 -0.000963
# Uninsured                                                    -0.001284
# Injury.deaths                                                -0.001605
# School Enrollment                                            -0.001926
# Homicide.rate                                                -0.001926
# Production.transportation.and.material.moving.occupations    -0.002568
# Total Population                                             -0.003852
# Median Earnings 2010                                         -0.004494
# dtype: float64

# %% [markdown]
# As in my teammember's results, the results of the 2008 and 2012 elections were the top features in the KNN. Interestingly, social features like diabetes and racial makeup are the highest demographic influencers after the election results. I plan to do a deeper dive into these demographic results next.

# %% [markdown]
# ## Part 5 Support Vector Classifier (SVC)

# %% [markdown]
# - We will use the standarized data

# %%
ss = preprocessing.StandardScaler()
X_train_ss = ss.fit_transform(X_train).tolist()
X_val_ss = ss.fit_transform(X_val).tolist()
X_test_ss = ss.fit_transform(X_test).tolist()

# %%
def computeAccuracy(myY_true, myY_pred):
    return metrics.accuracy_score(y_true = myY_true, y_pred = myY_pred)

# Create confusion matrix and print report 
def showMetrics(myTitle, myY_true, myY_pred):
    confusion_matrix =  pd.crosstab(index=np.ravel(myY_true), columns=myY_pred.ravel(), rownames=['Actual'], colnames=['Predicted'])
    sns.heatmap(confusion_matrix, annot=True, square=False, fmt='', cbar=False)
    plt.title(myTitle, fontsize = 15)
    plt.show()
    print(metrics.classification_report(y_true = myY_true, y_pred = myY_pred))

# %% [markdown]
# ### 5.1 - Default Model

# %%
from sklearn.svm import SVC

# %%
svc = SVC(kernel ='rbf')

# %%
svc.fit(X_train_ss, y_train)
# Out:
# SVC()

# %%
from sklearn import metrics
#Accuracy Train
pred_train = svc.predict(X_train_ss)
print("Accuracy Scores (Train): ",computeAccuracy(y_train, pred_train))

#Accuracy Test
pred_test = svc.predict(X_test_ss)
print("Accuracy Scores (Test): ",computeAccuracy(y_test, pred_test))

#Accuracy validation
pred_val = svc.predict(X_val_ss)
print("Accuracy Scores (Valid): ",computeAccuracy(y_val, pred_val), "\n")
# Out:
# Accuracy Scores (Train):  0.9824120603015075
# Accuracy Scores (Test):  0.9614767255216693
# Accuracy Scores (Valid):  0.9558232931726908

# %%
showMetrics("Confusion Matrix of Default SVC", y_val, pred_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.86        78
#            1       0.97      0.98      0.97       420
#
#     accuracy                           0.96       498
#    macro avg       0.92      0.91      0.91       498
# weighted avg       0.96      0.96      0.96       498

# %% [markdown]
# ### 5.2 GridSearch CV for Gamma and C values

# %%
svc = SVC()
value = [0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10 ,100, 1000]
params = {'C': value,
          'gamma': value,
           'kernel': ['rbf']}

grid = GridSearchCV(estimator=svc, param_grid=params, verbose=1, cv=5, n_jobs=-1)

# %%
grid.fit(X_train_ss, y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done 398 out of 405 | elapsed:   14.8s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 405 out of 405 | elapsed:   15.0s finished
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [1e-05, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100,
#                                1000],
#                          'gamma': [1e-05, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100,
#                                    1000],
#                          'kernel': ['rbf']},
#              verbose=1)

# %%
grid.best_estimator_
# Out:
# SVC(C=1000, gamma=0.0001)

# %%
gs_svc = SVC(kernel='rbf', C=1000, gamma=0.0001)
gs_svc.fit(X_train_ss, y_train)
# Out:
# SVC(C=1000, gamma=0.0001)

# %%
#Accuracy Train
pred_train = gs_svc.predict(X_train_ss)
print("Accuracy Scores (Train): ",computeAccuracy(y_train, pred_train))

#Accuracy validation
pred_val = gs_svc.predict(X_val_ss)
print("Accuracy Scores (Valid): ",computeAccuracy(y_val, pred_val), "\n")
# Out:
# Accuracy Scores (Train):  0.978391959798995
# Accuracy Scores (Valid):  0.963855421686747

# %%
showMetrics("Confusion Matrix of Best C & gamma SVC", y_val, pred_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        78
#            1       0.98      0.98      0.98       420
#
#     accuracy                           0.96       498
#    macro avg       0.93      0.93      0.93       498
# weighted avg       0.96      0.96      0.96       498

# %% [markdown]
# - The best GridsearchCV model higher the accuracy, precision, f1 similar to the default model, so it performs similarily than the default model.
# - The best GridsearchCV model has a specificity 5% higher than those of default model which improve the performance in predicting class 0 (Democractic Winner)
# - The best model is not overfitting as the accuracy rate of train and validation set are high and close to each other.

# %% [markdown]
# ### 5.3 SVC fitted with KPCA

# %% [markdown]
# - Our original train set has 44 features which comtains some non-linear structure.
# - So, we will use the KPCAs to the high dimensional feature space, thus it can capture the non-linear structure among features, which can improve the performance of our model.

# %%
from sklearn.decomposition import KernelPCA
kpca = KernelPCA(n_components=100, kernel='rbf', n_jobs=-1, remove_zero_eig=True)
kpca.fit(X_train_ss)
X_train_kpca = kpca.transform(X_train_ss)
X_test_kpca = kpca.transform(X_test_ss)
X_val_kpca = kpca.transform(X_val_ss)

# %%
X_train_kpca = X_train_kpca[:, 0:80]
X_test_kpca = X_test_kpca[:, 0:80]
X_val_kpca = X_val_kpca[:, 0:80]

# %%
svc = SVC()
value = [0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10 ,100, 1000]
params = {'C': value,
          'gamma': value,
           'kernel': ['rbf']}

grid = GridSearchCV(estimator=svc, param_grid=params, verbose=1, cv=5, n_jobs=-1)

# %%
grid.fit(X_train_kpca, y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 312 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=-1)]: Done 398 out of 405 | elapsed:   20.4s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 405 out of 405 | elapsed:   21.2s finished
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [1e-05, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100,
#                                1000],
#                          'gamma': [1e-05, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100,
#                                    1000],
#                          'kernel': ['rbf']},
#              verbose=1)

# %%
grid.best_estimator_
# Out:
# SVC(C=10, gamma=0.01)

# %%
gs_svc = SVC(kernel='rbf', C=10, gamma=0.01)
gs_svc.fit(X_train_kpca, y_train)
# Out:
# SVC(C=10, gamma=0.01)

# %%
#Accuracy Train
pred_train = gs_svc.predict(X_train_kpca)
print("Accuracy Scores (Train): ",computeAccuracy(y_train, pred_train))

#Accuracy validation
pred_val = gs_svc.predict(X_val_kpca)
print("Accuracy Scores (Valid): ",computeAccuracy(y_val, pred_val), "\n")
# Out:
# Accuracy Scores (Train):  0.9673366834170855
# Accuracy Scores (Valid):  0.9598393574297188

# %%
showMetrics("Confusion Matrix of SVC with KPCAs", y_val, pred_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87        78
#            1       0.97      0.98      0.98       420
#
#     accuracy                           0.96       498
#    macro avg       0.93      0.91      0.92       498
# weighted avg       0.96      0.96      0.96       498

# %% [markdown]
# - The best KPCAs model in Part 3 have similiar sensitivity, accuracy, precision, f1 similar to the Part 2  GridSearach CV model, so it performs similarily to the part-2 model.
# - The KPCAs model in Part 3 is  more slightly overfitting than the Part-2 model as the gap between accuracy rate of train and validation set is 1.2% which is higher than the gap in part 2 of 0.7%.
# - So, we will pick the SVC model in Part 2 as our best model and adjust class weight in the next section.

# %% [markdown]
# ### 5.4 SVC with adjusted class weight

# %% [markdown]
# - To improve the prediction performance on class 0.
# - we will compute and  specify class_weights so that the higher class-weight means you want to put more emphasis on a class. We will put more weight on the class 0 relative to class 1

# %%
# Create an array with the colors 
colors = ["#0d00ff", "#ed7572"]
sns.set_palette(sns.color_palette(colors))
plt.hist(y_train.ravel());

# %%
# Compute class_weights
from sklearn.utils import class_weight
class_weights = class_weight.compute_class_weight('balanced', np.unique(y_train),y_train)
print(class_weights)
# Out:
# [3.19935691 0.59261465]

# %%
gs_svc = SVC(kernel='rbf', C=1000, gamma=0.0001, class_weight={0: 3, 1: 0.59})

# %%
gs_svc.fit(X_train_ss, y_train)
# Out:
# SVC(C=1000, class_weight={0: 3, 1: 0.59}, gamma=0.0001)

# %%
#Accuracy Train
pred_train = gs_svc.predict(X_train_ss)
print("Accuracy Scores (Train): ",computeAccuracy(y_train, pred_train))

#Accuracy validation
pred_val = gs_svc.predict(X_val_ss)
print("Accuracy Scores (Valid): ",computeAccuracy(y_val, pred_val), "\n")
# Out:
# Accuracy Scores (Train):  0.9668341708542714
# Accuracy Scores (Valid):  0.9518072289156626

# %%
showMetrics("Confusion Matrix of the Best SVC", y_val, pred_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.95      0.86        78
#            1       0.99      0.95      0.97       420
#
#     accuracy                           0.95       498
#    macro avg       0.89      0.95      0.92       498
# weighted avg       0.96      0.95      0.95       498

# %% [markdown]
# - Comparing the new model to the previous model, The specificiy of the new models have significantly improved (10% higher) from the previous which do not specify class weight.
# - These implies the better prediction of class 0 of the new models with class-weight
# - The accuracy rate are also high and not overfitting
# - Thus, the new models with class weight gives better specificity for hyper-parameter tuning. We focus on class 1 which is the minority class (only account for 20% of dataset) so we need to put higher class-weight to put more emphasis on a class 0.

# %% [markdown]
# ## <font color =blue> Model Comparison with Test Set

# %%
#This function prints the test set performance for each model
# Codes are editted from Prof's Ustun class notbook
def compareClssifier(name,clf, X_train, y_train_cat, X_test, y_test_cat ):
    clf.fit(X_train, np.ravel(y_train_cat))
    predicted = clf.predict(X_test)
    confusion_matrix =  pd.crosstab(index=np.ravel(y_test_cat), columns=predicted.ravel(), rownames=['Expected'], colnames=['Predicted'])
    sns.heatmap(confusion_matrix, annot=True, square=False, fmt='', cbar=False)
    accuracy = np.round(metrics.accuracy_score(y_test_cat , predicted),3)
    plt.title(name + "  " , fontsize = 15)
    plt.show()
    print (metrics.classification_report(y_test_cat,predicted))

# %%
random_seed = 54

best_dt = DecisionTreeClassifier(class_weight={0: 2, 1: 1}, criterion='entropy',
                       max_depth=5, min_samples_split=50, random_state=random_seed)
best_lg =  LogisticRegression(solver = 'liblinear', 
                              penalty = 'l1', 
                              C = .06,
                              tol = .007,
                              random_state = random_seed)
best_rf = RandomForestClassifier(criterion= 'entropy' ,max_features= 'auto',max_depth=3, min_samples_split=1000
                                ,n_estimators=5,random_state = random_seed)

best_knn = KNeighborsClassifier(n_neighbors=15)
best_svc = SVC(kernel='rbf', C=1000, gamma=0.0001, class_weight={0: 3, 1: 0.59})




#create an array of classifiers
names = ["The Best Decision Tree", "The Best Logistic Regression", "The Best Random Forest", 
         "The Best KNN", "The Best SVC"]
classifiers= [best_dt, best_lg, best_rf, best_knn, best_svc]

#loop through the classifiers
for name, clf in zip(names, classifiers):
    compareClssifier(name,clf, X_train_ss, y_train, X_test_ss, y_test )
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.94      0.81        97
#            1       0.99      0.93      0.96       526
#
#     accuracy                           0.93       623
#    macro avg       0.85      0.93      0.89       623
# weighted avg       0.95      0.93      0.94       623
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89        97
#            1       0.98      0.97      0.98       526
#
#     accuracy                           0.96       623
#    macro avg       0.92      0.94      0.93       623
# weighted avg       0.96      0.96      0.96       623
#               precision    recall  f1-score   support
#
#            0       0.73      0.34      0.46        97
#            1       0.89      0.98      0.93       526
#
#     accuracy                           0.88       623
#    macro avg       0.81      0.66      0.70       623
# weighted avg       0.86      0.88      0.86       623
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89        97
#            1       0.98      0.98      0.98       526
#
#     accuracy                           0.96       623
#    macro avg       0.93      0.93      0.93       623
# weighted avg       0.96      0.96      0.96       623
#               precision    recall  f1-score   support
#
#            0       0.80      0.97      0.88        97
#            1       0.99      0.96      0.97       526
#
#     accuracy                           0.96       623
#    macro avg       0.90      0.96      0.93       623
# weighted avg       0.96      0.96      0.96       623

# %% [markdown]
# - The SVC model built with kernel RBF performs the best with the high accuracy rate 96% and other metrics such as F1, Precision, Specificity (over 97%) are also higher than other models which indicates the good performance in prediction both target classes.
# - The Logistic regression model is the second best model with has the accuracy rate as high as the Best SVC model, but slightly lower specificity.
# - All models have high accuracy rate, F1, sensitivity over 90-95%
# - Adjusting class weight to put more emphasis on the minority class has significantly improved the specificity (increase over 7%)
# - All models are not overfitting as the accuracy rates of training and test sets are closed to each other (less than 1.5% gap)

# %% [markdown]
# ## <font color =blue> Conclusion and Experiment Results

# %% [markdown]
# #### Decision Tree

# %% [markdown]
# - The best model has high accuracy of 93%. The f1 is as high as 97% respectively. which is higher than the default model, so it performs better than the default model. The specificity is 85%.
# - We have reduce the effect of an imbalanced target class as we specify the class weight and use the balanced accuracy score in GridSearchCV.
# - The obvious improvement is that the GridSearchCV model can predict both class 0 (minority) and class 1(majority) well .
# - Comparing to the default model, the best model is less overfitting as the accuracy rate of train and test set are high and close to each other.
# - From the best Decision Tree in part 1.2, we can indentify that the "2012 winner" variable is the most important feature which is located at the root node.
# - The second most important feature is the "median ages.
# - Other demographic features such as race, and education level features also have a high influence on the target variable.
# - Comparing to the health condition and surrounding factors, the demographic features such as race and education level have more influence on election winner.

# %% [markdown]
# #### Logistic Regression

# %% [markdown]
#  - The best model had a 98.44% accuracy. This out performed the base model by over 4%.
#  - The tuned model utilized l2 regularization and pushed over 50% of the features to 0.
#  - We can see from a probability plot that out model is performing as expected in terms of high probabisitic predictions. Essentially, we are very sure of our estimates with this model.
#  - After analyzing the coefficients, can see that having at least a Bachelor's Degree, and what the counties party choice in 2008 and 2012 were the most important predictors.

# %% [markdown]
# #### Random Forest

# %% [markdown]
# - In the oprimized model I was able to get accuracy of 90.5%  This went down from 97% I got with the basic model.  That said my test and training model accuracy is closer.
# - From a random forest point of view there are 7 key features neeed to predict the out come of a county. 2008 winer, HV,prevelance rate,2012 winner, graduate degree, at least a bachelors degree, farming, fishing and forestry occupation.
# - this is telling me that knowing the education of the county and knowing the party winner form the priot two elections are all very important.
# - farming, fishing and forest seems to be an interesting on for why that is so important.
# - Suprisingly with random forest the ethniticity doesn't really factor into the election
# - The two interesting ones of importance that stick out is HIV rate and homicide rate

# %% [markdown]
# #### K-Nearest Neighbors

# %% [markdown]
# - The number of neighbors that produced the highest accuracy in the testing set is 35
# - This produces an accuracy of 97.3% with a recall value of 0.990 and precision of 0.977. The F1 score is 0.984
# - Like the other models, 2012 and 2008 winners are found to be the most important features. However, we had to use permutation_importance to find these rankings

# %% [markdown]
# #### Support Vector Machine

# %% [markdown]
# - Comparing other models, The specificity of the SVC models have significantly higher than other models (95% vs 85%).
# - These implies the better prediction of class 0 of the SVC models with class-weight
# - The accuracy rate are also as high as 96% and F1 is 98%.
# - The SVC model is not overfitting as the accuracy rate of test set is close to that of train set.

# %% [markdown]
# ## <font color =blue> Research questions results

# %% [markdown]
# ### 1.  What variables overall are most important to predicting the outcome of an election?
# - The most important variables to predicting the outcome of an election are the winning result from the previous election 2012.
# - Other demograhic variables related to race, education level, median ages, and household condition also have a high influence on the target variable as their important scores are significantly higher than other features.
# - Comparing to the features that are related to characteristics of voters, the features that are related to surrounding of counties has a less influence on the prediction outcome.

# %% [markdown]
# ### 2. What role, if any, do demographic characteristics play in the outcome of an election?

# %% [markdown]
# - Based on the classifier, we can conclude that the median age and race features play important roles on the voters' preferences on a political party. Demographic features related to race, education level, and median age also have a high influence on the election outcome, whereas the County factors such as crime rate has less influence on the election outcome
# - For example, if the median age of the voters in the county is less than 38.15 years old, it is likely that the democatic candidate will win the election for that county.
# - Additionally, if the county has the percentage of Asian American voters less than 2.5%, the democatic candidate will be likely to win the election. On the other hand, if the percentage of White voters are less than 47%, the Republican candidate has a high chance to win the election.
# - The education level also play an important role in which if the percentage of voters in the county who has at keast bachelor's degree is less than 18%, the Republican candidate is likely to win the election for that county.

# %% [markdown]
# ## <font color =blue> Conclusion

# %% [markdown]
# - The most important feature is the previous election results in 2012. Demographic features related to race, education level, and median age also have a high influence on the election outcome. County factors such as crime rate has less influence on the election outcome
#
# - From all classifiers, all models have high accuracy rate, F1, sensitivity over 90-95%, but the SVC model built with kernel RBF performs the best with the high accuracy rate and other metrics such as F1, Precision, Specificity are also higher than other models which indicates the good performance in prediction both target classes. Adjusting class weight to put more emphasis on the minority class has significantly improved the specificity (increase over 7%). The Logistic regression model is the second best model with has the accuracy rate as high as the Best SVC model, but slightly lower specificity.
#
# - All models are not overfitting as the accuracy rates of training and test sets are closed to each other (less than 1.5% gap)

# %% [markdown]
# ## <font color =blue> Future Studies

# %% [markdown]
# - We would like to apply our final classification models to the new dataset to predict the recent election outcome in 2020 to see if the actual results align with our prediction.

# %% [markdown]
# ## <font color =blue> References

# %% [markdown]
# Dataset retrieved from:
# https://public.opendatasoft.com/explore/dataset/usa-2016-presidential-election-by-county/table/?disjunctive.state.
#
# [1]  Pew Research Center: An examination of the 2016 electorate, based on validated voters August, 2018 retrieved from https://www.pewresearch.org/politics/2018/08/09/an-examination-of-the-2016-electorate-based-on-validated-voters/
#
# [2]  Kurtbus I., The Factors Influencing Voting Preferences in Local Elections An Empirical Study. International Journal of Humanities and Social Science. Sep, 2015 retrieved from https://www.researchgate.net/publication/295095195_The_Factors_Influencing_Voting_Preferences_in_Local_Elections_An_Empirical_Study

# %% [markdown]
# ## <font color =blue> Contributions

# %% [markdown]
# #### For data preprocessing, cleaning, and exploration, all team members worked together via Google CoLab to preprocess data and perform data exploration. We have divided the tasks equally in which each of us is responsible to build the models with different Machine Learning algorithms. The specific details of individual contribution are discussed below.

# %% [markdown]
# #### Markus Olson:

# %% [markdown]
# - Assisted in Project Report and Milestone Write-up and prepared the presentation slides
# - Built random forest model with default parameters and Grid search
# - Identified random forest important features
# - Answered research question the team has posed
# - Assisted in the comentray on the data evaluation
# - Found the data set
# - Organized and contribute to team meetings
# - Did the video for the project proposal

# %% [markdown]
# #### Sarah Danielson:

# %% [markdown]
# - Assisted in Project Report and Milestone Write-up and prepared the presentation slides
# - Built the KNN classifier and used variety of k-values to find the optimal number of neighbors
# - Helped create the 2008 and 2012 winner variables
# - Assisted in commentary and edited the Milestone Write-up
# - Contribute in team meetings
# - Experiment with different types of distances (for example, Minkowski, Euclidean, and Manhattan) to see if that improves the accuracy of KNN. I also plan to visualize the decision boundaries of the clusters, perhaps using PCA to create the graph. I will also look for more ways to understand the feature importance and demographic information.

# %% [markdown]
# #### Amy Aumpansub:

# %% [markdown]
# - Assisted in Project Report and Milestone Write-up and prepared the presentation slides
# - Find the references and helped in editing the abstract and conclusion sections
# - Built the decision trees with the default parameters and GridSearchCV
# - Identified the important features and compare the decision tree models
# - Performed feature selection and visualize the most and least important features using ExtraTreesClassifier
# - Built SVC model with hyper parameter tuning
# - Answered some of research questions based on the model outputs and found results

# %% [markdown]
# #### Charles Brantley:

# %% [markdown]
# - Assisted in Project Report and Milestone Write-up and prepared the presentation slides
# - Built a base logistic regression model and performed tuning via randomized and grid search
# - Evaluated the best model and explored metrics
# - Explored coefficients and features in the model
# - Explored elastic net regression and see if I can really shrink the number of parameters the ML model needs.
